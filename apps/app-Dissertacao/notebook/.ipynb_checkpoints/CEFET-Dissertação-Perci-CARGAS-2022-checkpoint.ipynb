# %% [markdown]
# <img src="logo-cefet.png" width="300">
#
# <h1> PPCIC Dissertação - 2021/2022
#     <br>
#     <br>
#     DETECÇÃO DE EVENTOS ADVERSOS ATRAVÉS DO TWITTER UTILIZANDO O METAMAP PARA O PORTUGUÊS DO BRASIL </h1>
# </br>
#
# <h2> Matéria: CIC1229 - TÓPICOS ESPECIAIS EM ALGORITMOS </h2>
# <h2> Aluno: Perciliano </h2>
# <h2> Orientadora: Kele Belloze </h2>
# <h3> Data: 29/06/2022 </h3>
#
# ---
#
# **Autor: Luiz Perciliano** -
# ***luiz.perciliano@eic.cefet-rj.br***

# %% [markdown]
# <b>Dados da pesquisa na base SCOPUS (541) e PubMed (188) - 729 documentos para análise</b>
#
# **A Fazer**
#
# 1. [x] Criado projeto no git para Fork e acompanhamento do Will
# 1. [ ] 6+ - Há um documento que não foi necessário baixar PDF, verificar este
# 1. [ ] Ler novos documentos de 2022
# 1. [ ] Analisr biblioteca Python do MetaMap
# 1. [ ] Ajustar documento / manual de instalação do Metamap
# 1. [ ] Documentos sem abstract serão deixados por último
# 1. [ ] Melhorar busca de massa de dados no Twitter com o Knime
# 1. [ ] Ajustar / rodar MetaMap com nova massa de dados
#
# ---
#
# [Projeto no GitHub](https://github.com/LuizPerciliano/Evento-Adverso-com-Metamap-e-Twitter-com-Portugues-Brasil)
#
# [Site da dissertação](https://www.overleaf.com/read/rtybccmfvfr7)
#
# [Manual de instalação do Metamap DFB 2021](https://www.overleaf.com/read/jsyhtqwwgccz)

# %% [markdown]
# # Preparar Infraesrtutura

# %% [raw]
# '''
# Alguns pacotes como wordcloud exigem em SO WiN instalação do Microsoft Visual C++ Build Tools no link abaixo:
# https://my.visualstudio.com/Downloads
# Escolher: Visual C++ Build Tools for Visual Studio 2015 with Update 3
# -- baixar a .iso e instalar por lá
# '''

# %%
print(f'Importar as bibliotecas necessárias e mapear a pasta do projeto.')
import os, re
import sys
import pandas as pd
import numpy as np
import datetime
import seaborn as sns

import nltk
#nltk.download()
from nltk.corpus import stopwords

from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
# %matplotlib inline

from google_trans_new import google_translator

from bs4 import BeautifulSoup
from bs4.formatter import HTMLFormatter
import requests
# Out:
# Importar as bibliotecas necessárias e mapear a pasta do projeto.

# %%
dict_colors = {
    'red':'\033[0;31m'
    ,'green':'\033[0;32m'
    ,'yellow':'\033[0;33m'
    ,'blue':'\033[0;34m'
    ,'blue_underline':'\033[4;34m'
    ,'roxo':'\033[0;35m'
    ,'ciano':'\033[0;36m'
    ,'cinza':'\033[0;37m'
    ,'black&red':'\033[0;31;40m'
    ,'close_color':'\033[m'
}

# %%
data_inicio = pd.Timestamp.now()
dataFormatada = data_inicio.strftime('%d-%m-%Y %H-%M-%S')
print(f"Iniciando o programa em: {dict_colors['blue_underline']}{dataFormatada}{dict_colors['close_color']}")
# Out:
# Iniciando o programa em: 29-06-2022 01-32-16

# %% [markdown]
# ## Verificar, atualizar e instalar se necessário python e módulos

# %%
## versao 3,9,0 estava funcionando
print('Local de instalação do Python:       ',sys.executable)
print('Versão do Python instalado e em uso: ',sys.version)
print('Informações da versão do Python:     ',sys.version_info)
print(f'Quantidade de CPU:                   {os.cpu_count()}')

# %%
print('Atualizando os módulos Python.')
#!pip install --upgrade pip

# %%
print('Instalando os módulos necessários.')
# print('')
#!pip install Unidecode -q
#!pip install sklearn
#!pip install wordcloud
#!pip install wget
#!pip install opencv-python #import cv2
#!pip install wand #wand=0.6.5
#!pip install jupyter_contrib_nbextensions
#!pip install pip-chill ## para verificar todos os mõdulos instalados para uma nova instalacao

# %%
print(f'Lista do conteúdo da pasta ...')
os.listdir(os.path.join('..','data'))
# Out:
# Lista do conteúdo da pasta ...
# ['base-qualis-06-06-2021.xlsx',
#  'bases_filtradas-completa-26-06-2022 00-37-39.xlsx',
#  'bases_filtradas-resumida-26-06-2022 00-37-39.xlsx',
#  'bases_filtradas_traduzida-26-09-2021.xlsx',
#  'bkp',
#  'fluxos-processos.drawio',
#  'pubmed-csv-naturallan-set-2022.csv',
#  'pubmed.csv',
#  'PubMed_Timeline_Results_by_Year-10-06-2021.csv',
#  'requiremets.txt',
#  'scopus-31-05-2022.csv',
#  'scopus.csv',
#  'stop_word_projeto.csv',
#  'stop_word_pt.csv']

# %%
pd.set_option("max_colwidth", 200)

# %% [markdown]
# # Carga de arquivo - Qualis

# %% [raw]
# print('Carregando pesquisa realizada na base Scopus.')
# '''
# Fonte: https://sucupira.capes.gov.br/sucupira/public/consultas/coleta/veiculoPublicacaoQualis/listaConsultaGeralPeriodicos.jsf
# Periódico do quadriênio 2013-2016
# '''
# arquivo_base_qualis = os.path.join('../data','base-qualis-06-06-2021.xlsx')
# raw_data_qualis = pd.read_excel(arquivo_base_qualis)
# raw_data_qualis

# %% [markdown]
# # Carga de arquivo - Scopus

# %%
print('Visualização do dataframe carregado da base scopus.')
arquivo_base_scopus = os.path.join('../data','scopus-31-05-2022.csv')
raw_data_scopus = pd.read_csv(arquivo_base_scopus, sep=",", delimiter=None, encoding='utf-8')
raw_data_scopus.head(3)
# Out:
# Visualização do dataframe carregado da base scopus.
#                                                       Authors  \
# 0                                                Aronson A.R.
# 1                   Kuhn M., Letunic I., Jensen L.J., Bork P.
# 2  Nikfarjam A., Sarker A., O'Connor k., Ginn R., Gonzalez G.
#
#                                                    Author(s) ID  \
# 0                                                  17933416200;
# 1                35345083400;6602771600;35548941900;7103061421;
# 2  36069663700;36976315000;56596185000;56596524300;56749066000;
#
#                                                                                                                                      Title  \
# 0                                                     Effective mapping of biomedical text to the UMLS Metathesaurus: the MetaMap program.
# 1                                                                                             The SIDER database of drugs and side effects
# 2  Pharmacovigilance from social media: Mining adverse drug reaction mentions using sequence labeling with word embedding cluster features
#
#    Year                                             Source title Volume Issue  \
# 0  2001  Proceedings / AMIA ... Annual Symposium. AMIA Symposium    NaN   NaN
# 1  2016                                   Nucleic Acids Research     44    D1
# 2  2015  Journal of the American Medical Informatics Association     22     3
#
#   Art. No. Page start Page end  ...  ISBN  CODEN   PubMed ID  \
# 0      NaN         17       21  ...   NaN    NaN  11825149.0
# 1      NaN      D1075    D1079  ...   NaN  NARHA  26481350.0
# 2      NaN        671      681  ...   NaN  JAMAF  25755127.0
#
#   Language of Original Document        Abbreviated Source Title Document Type  \
# 0                       English                  Proc AMIA Symp       Article
# 1                       English              Nucleic Acids Res.       Article
# 2                       English  J. Am. Med. Informatics Assoc.       Article
#
#   Publication Stage                          Open Access  Source  \
# 0             Final                                  NaN  Scopus
# 1             Final         All Open Access, Gold, Green  Scopus
# 2             Final  All Open Access, Hybrid Gold, Green  Scopus
#
#                   EID
# 0   2-s2.0-0035752429
# 1  2-s2.0-84979503522
# 2  2-s2.0-84927943705
#
# [3 rows x 54 columns]

# %% [markdown]
# ## Análise do dataframe - SCOPUS

# %% [markdown]
# ### Colunas, dados nulos e tipos de dados

# %%
print('Verificando colunas, dados nulos e tipos de dados')
raw_data_scopus.info()
# Out:
# Verificando colunas, dados nulos e tipos de dados
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Authors                        541 non-null    object
#  1   Author(s) ID                   541 non-null    object
#  2   Title                          541 non-null    object
#  3   Year                           541 non-null    int64
#  4   Source title                   541 non-null    object
#  5   Volume                         454 non-null    object
#  6   Issue                          236 non-null    object
#  7   Art. No.                       145 non-null    object
#  8   Page start                     407 non-null    object
#  9   Page end                       396 non-null    object
#  10  Page count                     3 non-null      float64
#  11  Cited by                       454 non-null    float64
#  12  DOI                            442 non-null    object
#  13  Link                           541 non-null    object
#  14  Affiliations                   537 non-null    object
#  15  Authors with affiliations      538 non-null    object
#  16  Abstract                       541 non-null    object
#  17  Author Keywords                375 non-null    object
#  18  Index Keywords                 492 non-null    object
#  19  Molecular Sequence Numbers     0 non-null      float64
#  20  Chemicals/CAS                  117 non-null    object
#  21  Tradenames                     20 non-null     object
#  22  Manufacturers                  2 non-null      object
#  23  Funding Details                274 non-null    object
#  24  Funding Text 1                 248 non-null    object
#  25  Funding Text 2                 29 non-null     object
#  26  Funding Text 3                 3 non-null      object
#  27  Funding Text 4                 0 non-null      float64
#  28  Funding Text 5                 0 non-null      float64
#  29  Funding Text 6                 0 non-null      float64
#  30  Funding Text 7                 0 non-null      float64
#  31  Funding Text 8                 0 non-null      float64
#  32  Funding Text 9                 0 non-null      float64
#  33  Funding Text 10                0 non-null      float64
#  34  References                     483 non-null    object
#  35  Correspondence Address         431 non-null    object
#  36  Editors                        94 non-null     object
#  37  Sponsors                       53 non-null     object
#  38  Publisher                      434 non-null    object
#  39  Conference name                162 non-null    object
#  40  Conference date                162 non-null    object
#  41  Conference location            34 non-null     object
#  42  Conference code                151 non-null    float64
#  43  ISSN                           467 non-null    object
#  44  ISBN                           138 non-null    object
#  45  CODEN                          199 non-null    object
#  46  PubMed ID                      329 non-null    float64
#  47  Language of Original Document  541 non-null    object
#  48  Abbreviated Source Title       540 non-null    object
#  49  Document Type                  541 non-null    object
#  50  Publication Stage              541 non-null    object
#  51  Open Access                    260 non-null    object
#  52  Source                         541 non-null    object
#  53  EID                            541 non-null    object
# dtypes: float64(12), int64(1), object(41)
# memory usage: 228.4+ KB

# %% [markdown]
# ### Quantidade de conteúdo único para cada coluna

# %%
print('Verificando quantidade de conteúdo único para cada coluna')
raw_data_scopus.nunique()
# Out:
# Verificando quantidade de conteúdo único para cada coluna
# Authors                          525
# Author(s) ID                     521
# Title                            539
# Year                              23
# Source title                     196
# Volume                           188
# Issue                             37
# Art. No.                         141
# Page start                       316
# Page end                         325
# Page count                         3
# Cited by                          81
# DOI                              442
# Link                             541
# Affiliations                     528
# Authors with affiliations        536
# Abstract                         530
# Author Keywords                  375
# Index Keywords                   492
# Molecular Sequence Numbers         0
# Chemicals/CAS                     85
# Tradenames                        18
# Manufacturers                      2
# Funding Details                  259
# Funding Text 1                   247
# Funding Text 2                    29
# Funding Text 3                     3
# Funding Text 4                     0
# Funding Text 5                     0
# Funding Text 6                     0
# Funding Text 7                     0
# Funding Text 8                     0
# Funding Text 9                     0
# Funding Text 10                    0
# References                       483
# Correspondence Address           419
# Editors                           67
# Sponsors                          47
# Publisher                         75
# Conference name                  128
# Conference date                  127
# Conference location               29
# Conference code                  121
# ISSN                             133
# ISBN                             110
# CODEN                             48
# PubMed ID                        329
# Language of Original Document      3
# Abbreviated Source Title         191
# Document Type                     10
# Publication Stage                  2
# Open Access                        7
# Source                             1
# EID                              541
# dtype: int64

# %% [markdown]
# ### Quantidade de conteúdo nulo para cada coluna

# %%
raw_data_scopus.isnull().sum()
# Out:
# Authors                            0
# Author(s) ID                       0
# Title                              0
# Year                               0
# Source title                       0
# Volume                            87
# Issue                            305
# Art. No.                         396
# Page start                       134
# Page end                         145
# Page count                       538
# Cited by                          87
# DOI                               99
# Link                               0
# Affiliations                       4
# Authors with affiliations          3
# Abstract                           0
# Author Keywords                  166
# Index Keywords                    49
# Molecular Sequence Numbers       541
# Chemicals/CAS                    424
# Tradenames                       521
# Manufacturers                    539
# Funding Details                  267
# Funding Text 1                   293
# Funding Text 2                   512
# Funding Text 3                   538
# Funding Text 4                   541
# Funding Text 5                   541
# Funding Text 6                   541
# Funding Text 7                   541
# Funding Text 8                   541
# Funding Text 9                   541
# Funding Text 10                  541
# References                        58
# Correspondence Address           110
# Editors                          447
# Sponsors                         488
# Publisher                        107
# Conference name                  379
# Conference date                  379
# Conference location              507
# Conference code                  390
# ISSN                              74
# ISBN                             403
# CODEN                            342
# PubMed ID                        212
# Language of Original Document      0
# Abbreviated Source Title           1
# Document Type                      0
# Publication Stage                  0
# Open Access                      281
# Source                             0
# EID                                0
# dtype: int64

# %% [markdown]
# ### Resumo Estatístico de Campos Numéricos

# %%
raw_data_scopus[['Year','Page count','Cited by']].describe()
# Out:
#               Year   Page count     Cited by
# count   541.000000     3.000000   454.000000
# mean   2016.147874   651.000000    24.984581
# std       4.450171   762.055772    74.734156
# min    1992.000000    11.000000     1.000000
# 25%    2014.000000   229.500000     3.000000
# 50%    2017.000000   448.000000    10.000000
# 75%    2020.000000   971.000000    25.000000
# max    2022.000000  1494.000000  1339.000000

# %% [markdown]
# ## Manutenção de dados

# %%
# Copiar dataframe para ajustes
df_scopus = raw_data_scopus.copy()

# %%
## Verificar se os dataframes nao são espelhos, ou seja, o mesmo df
print(id(df_scopus),id(raw_data_scopus))
# Out:
# 1967119189712 1968275492960

# %%
print('Listar colunas')
df_scopus.columns
# Out:
# Listar colunas
# Index(['Authors', 'Author(s) ID', 'Title', 'Year', 'Source title', 'Volume',
#        'Issue', 'Art. No.', 'Page start', 'Page end', 'Page count', 'Cited by',
#        'DOI', 'Link', 'Affiliations', 'Authors with affiliations', 'Abstract',
#        'Author Keywords', 'Index Keywords', 'Molecular Sequence Numbers',
#        'Chemicals/CAS', 'Tradenames', 'Manufacturers', 'Funding Details',
#        'Funding Text 1', 'Funding Text 2', 'Funding Text 3', 'Funding Text 4',
#        'Funding Text 5', 'Funding Text 6', 'Funding Text 7', 'Funding Text 8',
#        'Funding Text 9', 'Funding Text 10', 'References',
#        'Correspondence Address', 'Editors', 'Sponsors', 'Publisher',
#        'Conference name', 'Conference date', 'Conference location',
#        'Conference code', 'ISSN', 'ISBN', 'CODEN', 'PubMed ID',
#        'Language of Original Document', 'Abbreviated Source Title',
#        'Document Type', 'Publication Stage', 'Open Access', 'Source', 'EID'],
#       dtype='object')

# %% [markdown]
# ### Ajustar nome das Colunas

# %%
columns_scopus = {
    'Authors':'autores_scopus',
    'Author(s) ID':'id_autores',
    'Title':'titulo_documento',
    'Year':'ano',
    'Source title':'titulo_fonte',
    'Volume':'volume',
    'Issue':'publicado',
    'Art. No.':'numero_documento',
    'Page start':'inicio_pagina',
    'Page end':'fim_pagina', 
    'Page count':'quantidade_paginas',
    'Cited by':'quantidade_citacoes',
    'DOI':'doi_scopus',
    'Link':'link_scopus',
    'Affiliations':'afiliacoes',
    'Authors with affiliations':'autores_com_filiacoes',
    'Abstract':'resumo',
    'Author Keywords':'palavras_chaves_autor',
    'Index Keywords':'palavras_chave_index',
    'Molecular Sequence Numbers':'numeros_sequencia_molecular' ,
    'Chemicals/CAS':'chemicals_cas',
    'Tradenames':'nomes_comerciais',
    'Manufacturers':'fabricantes',
    'Funding Details':'detalhes_financiamento',
    'Funding Text 1':'texto_financiamento_1',
    'Funding Text 2':'texto_financiamento_2',
    'Funding Text 3':'texto_financiamento_3',
    'Funding Text 4':'texto_financiamento_4', # do 4 ao 10 são novas colunas
    'Funding Text 5':'texto_financiamento_5',
    'Funding Text 6':'texto_financiamento_6',
    'Funding Text 7':'texto_financiamento_7',
    'Funding Text 8':'texto_financiamento_8',
    'Funding Text 9':'texto_financiamento_9',
    'Funding Text 10':'texto_financiamento_10',
    'References':'referencias',
    'Correspondence Address':'endereco_correspondencia',
    'Editors':'editores',
    'Sponsors':'patrocinadores',
    'Publisher':'editor',
    'Conference name':'nome_conferencia',
    'Conference date':'data_conferencia',
    'Conference location':'local_conferencia',
    'Conference code':'codigo_conferencia',
    'ISSN':'issn_scopus',
    'ISBN':'isbn',
    'CODEN':'coden',
    'PubMed ID':'id_pubmed',
    'Language of Original Document':'idioma_original',
    'Abbreviated Source Title':'titulo_abreviado_fonte',
    'Document Type':'tipo_documento',
    'Publication Stage':'etapa_publicacao',
    'Open Access':'acesso_livre',
    'Source':'fonte',
    'EID':'eid',
}

# %%
df_scopus = df_scopus.rename(columns=columns_scopus)

# %% [markdown]
# ### Criação de colunas

# %%
# manter uma coluna padrão, a princípio estes não se repetem e podem ser critério de eliminação de duplicata junto com título
df_scopus["doi"] = df_scopus["doi_scopus"]

# manter uma coluna padraa, a princípio estes não se repetem e podem ser critério de eliminação de duplicata*
df_scopus["titulo_documento_scopus"] = df_scopus["titulo_documento"]

# %%
# Criando novas colunas baseadas em antigas para ajustes
df_scopus["inicio_pagina_"] = df_scopus["inicio_pagina"]
df_scopus["fim_pagina_"] = df_scopus["fim_pagina"]
df_scopus['status_pagina']=True

# %% [markdown]
# ### Manutenção nas colunas de páginas

# %% [markdown]
# #### Limpeza em registro com letras e sinais
# <br>
# Campos do tipo objects que precisam ser tratados para ser transformados em int
# <br>
# Exemplo de traumas: '1038.e1' # ver se é possível tratar gericamente com regex

# %%
print(df_scopus['inicio_pagina_'].unique())
# Out:
# ['17' 'D1075' '671' '115' '196' '328' '343' '914' '25' '777' '589' nan
#  '331' '217' '789' '813' '23' '73' '1019' '148' '97' '739' '206' '228'
#  '631' '522' '1075' '841' '333' '152' '221' '443' '674' '876' '428' '318'
#  '954' '529' '997' '434' '1244' '280' '293' '139' '95' '160' '268' '122'
#  '824' '99' '737' '60' '143' '602' '334' '1580' '1' '3' '1077' '482' '191'
#  '902' '354' '559' '581' '1011' '1057' 'e79' '62' '92' '1274' '595' '177'
#  '549' '822' '2077' '890' '2790' '467' '39' '491' '13' '121' '111' '294'
#  '536' '153' '224' '1779' '254' '525' '882' '727' '161' '487' '682' '823'
#  '1414' '235' '91' '545' '147' '1675' '55' '763' '56' '67' '380' '643'
#  '272' '120' '150' '243' '64' '1270' '387' '123' '661' '163' '22' '687'
#  '65' '31' '1618' '149' '925' '247' '383' '2922' '57' '646' '913' '528'
#  '300' '306' '47' '90' '665' '755' '621' '1154' '2022' '288' '227' '33'
#  '548' '1030' 'S39' '456' '346' '75' '184' '679' '43' '260' '27' '61'
#  '1143' '4791' '1945' '237' '311' '496' '948' '961' '1232' '96' '435' '85'
#  '943' '63' '2059' '1046' '1032' '454' '391' '1339' '571' '592' '642'
#  '577' '185' '614' '567' '612' '644' '775' '182' '189' '37' '695' '552'
#  '915' '322' '339' '984' '499' '72' '699' '604' '116' '511' '917' '137'
#  '216' '1371' '996' '573' '176' '169' '103' '1147' '164' '794' '171'
#  '2593' '3015' '423' '127' '319' '1309' '2349' '1093' '313' '316' '51'
#  '18' '702' '1065' '492' '242' '839' '1150' '1105' '706' '2777' '569'
#  '126' '259' '83' '258' '388' '6093' '360' '1051' '782' '762' '106' '89'
#  '1252' '190' '396' '523' '285' '605' '615' '442' '266' '20' '158' '1136'
#  'e137' '2184' '413' '807' '198' '860' '12' '45' '848' '743' '405' '4325'
#  '53' '539' '170' '424' '296' '713' '155' '609' '8' '964' '407' '1235'
#  '2112' '108' '87' '505' '1207' '307' '833' '1110' '86' '585' '418' '1605'
#  '2609' '104' '420' '1129' '1291' '49' '273' '638' '452' '29' '1047' '79'
#  '15' '394' '1013' '113' '650' '274' '1004' '923']

# %%
## campos objects q precisam ser limpos e transformados em int
print(df_scopus['fim_pagina_'].unique())
# Out:
# ['21' 'D1079' '681' '128' '207' '337' '350' '920' '32' '790' '599' nan
#  '336' '226' '804' '821' '30' '81' '1026' '158' '104' '743' '217' '234'
#  '638' '531' '1089' '844' '349' '164' '227' '454' '684' '881' '434' '332'
#  '961' '533' '1003' '443' '1253' '287' '310' '153' '109' '178' '279' '132'
#  '832' '111' '743.e3' '80' '149' '612' '341' '1582' '5' '12' '10' '1084'
#  '488' '199' '909' '360' '562' '592' '1018' '1064' 'e86' '76' '100' '1283'
#  '674' '601' '181' '554' '841' '2083' '297' '896' '2797' '476' '46' '497'
#  '131' '97' '119' '8' '301' '539' '169' '233' '1788' '258' '529' '886'
#  '734' '166' '491' '686' '828' '1426' '245' '96' '549' '156' '1680' '59'
#  '767' '64' '86' '71' '386' '647' '125' '250' '72' '1279' '394' '133'
#  '669' '170' '691' '38' '1626' '157' '937' '678' '253' '391' '2931' '65'
#  '654' '307' '55' '99' '671' '766' '213' '629' '1159' '2028' '291' '251'
#  '42' '557' '1039' 'S43' '461' '353' '82' '171' '688' '48' '265' '913'
#  '1151' '41' '192' '4809' '1953' '248' '362' '314' '500' '950' '1243'
#  '107' '457' '89' '947' '77' '2066' '1056' '1038.e1' '463' '401' '1350'
#  '582' '668' '579' '196' '35' '127' '618' '571' '444' '616' '652' '785'
#  '188' '34' '212' '102' '57' '701' '555' '924' '326' '343' '993' '327' '2'
#  '510' '70' '951' '708' '130' '610' '264' '120' '515' '923' '26' '141'
#  '231' '1373' '1000' '172' '110' '238' '168' '798' '177' '651' '2607'
#  '3020' '300' '137' '58' '324' '1317' '45' '2359' '1097' '325' '52' '11'
#  '67' '43' '27' '706' '115' '1069' '303' '496' '246' '1116' '711' '2786'
#  '577' '268' '94' '392' '6096' '367' '1060' '784' '114' '92' '101' '194'
#  '411' '530' '289' '448' '28' '239' '161' 'e148' '2192' '421' '812' '202'
#  '869' '18' '870' '746' '410' '4330' '60' '150' '402' '51' '490' '733'
#  '543' '174' '427' '723' '29' '74' '418' '1245' '2123' '117' '53' '514'
#  '1224' '316' '1111' '590' '772' '1610' '2611' '429' '237' '1131' '1299'
#  '282' '456' '446' '36' '1048' '56' '24' '398' '393' '47' '1017' '62'
#  '359' '118' '280' '123' '329']

# %%
## alterar dados com letras e ponto
df_scopus.query('eid == "2-s2.0-85009726534" | eid == "2-s2.0-85077694717" ')[['eid','inicio_pagina','fim_pagina_','ano','quantidade_citacoes','quantidade_paginas','id_pubmed','titulo_documento']]
# Out:
#                     eid inicio_pagina fim_pagina_   ano  quantidade_citacoes  \
# 56   2-s2.0-85009726534           737      743.e3  2017                 42.0
# 242  2-s2.0-85077694717          1032     1038.e1  2020                  8.0
#
#      quantidade_paginas   id_pubmed  \
# 56                  NaN  28110055.0
# 242                 NaN  31857264.0
#
#                                                                                                                     titulo_documento
# 56        Adverse and Hypersensitivity Reactions to Prescription Nonsteroidal Anti-Inflammatory Agents in a Large Health Care System
# 242  Natural Language Processing Combined with ICD-9-CM Codes as a Novel Method to Study the Epidemiology of Allergic Drug Reactions

# %%
df_scopus.loc[df_scopus['eid'] == "2-s2.0-85009726534", 'fim_pagina_'] = 743
df_scopus.loc[df_scopus['eid'] == "2-s2.0-85077694717", 'fim_pagina_'] = 1038

# %%
df_scopus.query('eid == "2-s2.0-85009726534" | eid == "2-s2.0-85077694717" ')[['eid','inicio_pagina','fim_pagina_','ano','quantidade_citacoes','quantidade_paginas','id_pubmed','titulo_documento']]
# Out:
#                     eid inicio_pagina fim_pagina_   ano  quantidade_citacoes  \
# 56   2-s2.0-85009726534           737         743  2017                 42.0
# 242  2-s2.0-85077694717          1032        1038  2020                  8.0
#
#      quantidade_paginas   id_pubmed  \
# 56                  NaN  28110055.0
# 242                 NaN  31857264.0
#
#                                                                                                                     titulo_documento
# 56        Adverse and Hypersensitivity Reactions to Prescription Nonsteroidal Anti-Inflammatory Agents in a Large Health Care System
# 242  Natural Language Processing Combined with ICD-9-CM Codes as a Novel Method to Study the Epidemiology of Allergic Drug Reactions

# %% [markdown]
# #### Limpeza em registro com letras
# <br>
# Expressao em regex que pega só dígitos

# %%
r = re.compile(r'\D')
df_scopus.inicio_pagina_.replace(r, '', regex = True, inplace=True)
df_scopus.fim_pagina_.replace(r, '', regex = True, inplace=True)

# %% [markdown]
# #### Limpeza em registros das colunas `inicio_pagina_` e `fim_pagina_` com valor `NaN`
# <br>
# As colunas `inicio_pagina_` e `fim_pagina_` que tiverem o valor NaN devem receber o valor = 0 e a coluna `status_pagina` deve ser marcada como False para todos os registros que tenham 0 em página

# %%
# 134 rows
df_scopus[df_scopus['inicio_pagina_'].isnull()][['inicio_pagina_','fim_pagina_','eid']]
# Out:
#     inicio_pagina_ fim_pagina_                 eid
# 11             NaN         NaN  2-s2.0-85016601538
# 20             NaN         NaN  2-s2.0-44649165797
# 40             NaN         NaN  2-s2.0-85112136998
# 44             NaN         NaN  2-s2.0-85041059362
# 45             NaN         NaN  2-s2.0-84977543021
# ..             ...         ...                 ...
# 511            NaN         NaN  2-s2.0-85077702402
# 522            NaN         NaN  2-s2.0-84982806193
# 531            NaN         NaN  2-s2.0-84922021504
# 534            NaN         NaN  2-s2.0-84922021355
# 538            NaN         NaN  2-s2.0-70350577030
#
# [134 rows x 3 columns]

# %%
# 145 rows
df_scopus[df_scopus['fim_pagina_'].isnull()][['inicio_pagina_','fim_pagina_','eid']]
# Out:
#     inicio_pagina_ fim_pagina_                 eid
# 11             NaN         NaN  2-s2.0-85016601538
# 20             NaN         NaN  2-s2.0-44649165797
# 40             NaN         NaN  2-s2.0-85112136998
# 44             NaN         NaN  2-s2.0-85041059362
# 45             NaN         NaN  2-s2.0-84977543021
# ..             ...         ...                 ...
# 531            NaN         NaN  2-s2.0-84922021504
# 534            NaN         NaN  2-s2.0-84922021355
# 538            NaN         NaN  2-s2.0-70350577030
# 539           1004         NaN  2-s2.0-73949125371
# 540            923         NaN  2-s2.0-73949125091
#
# [145 rows x 3 columns]

# %%
## 11 registros que precisam ser ajustados = inicio e fim de páginas devem estar zerados
## é a diferença das colunas anteriores: 145 - 134
df_scopus.loc[
    (df_scopus['inicio_pagina_'].notnull()) & (df_scopus['fim_pagina_'].isnull())
]
# Out:
#                                                                                   autores_scopus  \
# 230  Gysbers M., Reichley R., Kilbridge P.M., Noirot L., Nagarajan R., Dunagan W.C., Bailey T.C.
# 281                                                    Gaebel J., Kolter T., Arlt F., Denecke K.
# 315                                                                                    Greibe K.
# 354                                                                        Garla V.N., Brandt C.
# 359                                                                                  Wedgwood J.
# 390                                                  Bhupatiraju R.T., Fung K.W., Bodenreider O.
# 399                                          Culbertson A., Fiszman M., Shin D., Rindflesch T.C.
# 403                                                            Tran N., Luong T., Krauthammer M.
# 453                             Hardardottir A., Heimisdottir M., Aronson A.R., Gunnarsdottir V.
# 539            Kilbridge P.M., Noirot L.A., Reichley R.M., Heard K.M., Dunagan W.C., Bailey T.C.
# 540                                                  De Lazzari C., Battaglia M., Pisanelli D.M.
#
#                                                                          id_autores  \
# 230  35299568400;6603460656;6602546163;8298753200;7202927147;7003952473;7201375998;
# 281                                57024126200;57023616300;45260928700;24331428400;
# 315                                                                    56043551000;
# 354                                                        36924810200;35513998400;
# 359                                                                    23500493500;
# 390                                             57202339135;55418163200;6603893164;
# 399                                  57170418300;8437484300;55449804300;6601978448;
# 403                                            57191195540;24766603200;24765892500;
# 453                                35299380200;35268622200;17933416200;15768914600;
# 539             6602546163;8298753200;6603460656;22034897300;7003952473;7201375998;
# 540                                              6603866499;35298609500;6603948495;
#
#                                                                                                                            titulo_documento  \
# 230                                                                            Natural language processing to identify adverse drug events.
# 281                            Extraction of Adverse Events from Clinical Documents to Support Decision Making Using Semantic Preprocessing
# 315                                                            Development of a SNOMED CT based national medication decision support system
# 354                 Knowledge-based biomedical word sense disambiguation: An evaluation and application to clinical document classification
# 359                                                                                           MQAF: a medical question-answering framework.
# 390                                                      MetaMap lite in excel: Biomedical named-entity recognition for non-technical users
# 399                                                 Semantic processing to identify adverse drug event information from black box warnings.
# 403                                                                               Mapping terms to UMLS concepts of the same semantic type.
# 453  Standardized documentation in physical therapy: testing of validity and reliability of the PT-ITC and mapping it to the Metathesaurus.
# 539                                                              Computerized surveillance for adverse drug events in a pediatric hospital.
# 540                                            Reporting adverse experiences related to drugs: an ontology-based tool to help the citizens.
#
#       ano  \
# 230  2008
# 281  2015
# 315  2013
# 354  2012
# 359  2005
# 390  2017
# 399  2013
# 403  2007
# 453  2008
# 539  2008
# 540  2008
#
#                                                                                                  titulo_fonte  \
# 230                                    AMIA ... Annual Symposium proceedings / AMIA Symposium. AMIA Symposium
# 281                                                              Studies in Health Technology and Informatics
# 315                                                              Studies in Health Technology and Informatics
# 354  Proceedings - 2012 IEEE 2nd Conference on Healthcare Informatics, Imaging and Systems Biology, HISB 2012
# 359                                    AMIA ... Annual Symposium proceedings / AMIA Symposium. AMIA Symposium
# 390                                                              Studies in Health Technology and Informatics
# 399                                    AMIA ... Annual Symposium proceedings / AMIA Symposium. AMIA Symposium
# 403                                    AMIA ... Annual Symposium proceedings / AMIA Symposium. AMIA Symposium
# 453                                    AMIA ... Annual Symposium proceedings / AMIA Symposium. AMIA Symposium
# 539                                    AMIA ... Annual Symposium proceedings / AMIA Symposium. AMIA Symposium
# 540                                    AMIA ... Annual Symposium proceedings / AMIA Symposium. AMIA Symposium
#
#     volume publicado numero_documento inicio_pagina fim_pagina  ...  \
# 230    NaN       NaN              NaN           961        NaN  ...
# 281    216       NaN              NaN          1030        NaN  ...
# 315    192       1-2              NaN          1147        NaN  ...
# 354    NaN       NaN          6366183            22        NaN  ...
# 359    NaN       NaN              NaN          1150        NaN  ...
# 390    245       NaN              NaN          1252        NaN  ...
# 399   2013       NaN              NaN           266        NaN  ...
# 403    NaN       NaN              NaN          1136        NaN  ...
# 453    NaN       NaN              NaN           964        NaN  ...
# 539    NaN       NaN              NaN          1004        NaN  ...
# 540    NaN       NaN              NaN           923        NaN  ...
#
#        tipo_documento  etapa_publicacao acesso_livre   fonte  \
# 230           Article             Final          NaN  Scopus
# 281  Conference Paper             Final          NaN  Scopus
# 315  Conference Paper             Final          NaN  Scopus
# 354  Conference Paper             Final          NaN  Scopus
# 359           Article             Final          NaN  Scopus
# 390  Conference Paper             Final          NaN  Scopus
# 399           Article             Final          NaN  Scopus
# 403           Article             Final          NaN  Scopus
# 453           Article             Final          NaN  Scopus
# 539           Article             Final          NaN  Scopus
# 540           Article             Final          NaN  Scopus
#
#                     eid                             doi  \
# 230  2-s2.0-73949088594                             NaN
# 281  2-s2.0-84951920778  10.3233/978-1-61499-564-7-1030
# 315  2-s2.0-84894346096  10.3233/978-1-61499-289-9-1147
# 354  2-s2.0-84871998344            10.1109/HISB.2012.12
# 359  2-s2.0-39049178417                             NaN
# 390  2-s2.0-85040532558  10.3233/978-1-61499-830-3-1252
# 399  2-s2.0-84901252203                             NaN
# 403  2-s2.0-56149098476                             NaN
# 453  2-s2.0-73949103021                             NaN
# 539  2-s2.0-73949125371                             NaN
# 540  2-s2.0-73949125091                             NaN
#
#                                                                                                                     titulo_documento_scopus  \
# 230                                                                            Natural language processing to identify adverse drug events.
# 281                            Extraction of Adverse Events from Clinical Documents to Support Decision Making Using Semantic Preprocessing
# 315                                                            Development of a SNOMED CT based national medication decision support system
# 354                 Knowledge-based biomedical word sense disambiguation: An evaluation and application to clinical document classification
# 359                                                                                           MQAF: a medical question-answering framework.
# 390                                                      MetaMap lite in excel: Biomedical named-entity recognition for non-technical users
# 399                                                 Semantic processing to identify adverse drug event information from black box warnings.
# 403                                                                               Mapping terms to UMLS concepts of the same semantic type.
# 453  Standardized documentation in physical therapy: testing of validity and reliability of the PT-ITC and mapping it to the Metathesaurus.
# 539                                                              Computerized surveillance for adverse drug events in a pediatric hospital.
# 540                                            Reporting adverse experiences related to drugs: an ontology-based tool to help the citizens.
#
#     inicio_pagina_ fim_pagina_  status_pagina
# 230            961         NaN           True
# 281           1030         NaN           True
# 315           1147         NaN           True
# 354             22         NaN           True
# 359           1150         NaN           True
# 390           1252         NaN           True
# 399            266         NaN           True
# 403           1136         NaN           True
# 453            964         NaN           True
# 539           1004         NaN           True
# 540            923         NaN           True
#
# [11 rows x 59 columns]

# %%
df_scopus.loc[df_scopus['inicio_pagina_'].isnull(), 'inicio_pagina_'] = 0
#df_scopus.loc[df_scopus['inicio_pagina_'].isnull(), 'fim_pagina_'] = 0
#df_scopus.loc[df_scopus['fim_pagina_'].isnull(), 'inicio_pagina_'] = 0
df_scopus.loc[df_scopus['fim_pagina_'].isnull(), 'fim_pagina_'] = 0

# %%
df_scopus[df_scopus['inicio_pagina_'].isnull()][['inicio_pagina_','fim_pagina_','eid']]
# Out:
# Empty DataFrame
# Columns: [inicio_pagina_, fim_pagina_, eid]
# Index: []

# %%
df_scopus[df_scopus['fim_pagina_'].isnull()][['inicio_pagina_','fim_pagina_','eid']]
# Out:
# Empty DataFrame
# Columns: [inicio_pagina_, fim_pagina_, eid]
# Index: []

# %% [markdown]
# #### Limpeza em registro com pelo menos umas das colunas com valor 'válido'
# <br>
# 11 registros em que uma das colunas tem valor e a outra não, foram zerdas acima, agora precisa zerar o par que tenha algum valor 'válido', pois com apenas um dos campos com valor, não é possível verificar a quantidade de páginas

# %%
df_scopus.query('inicio_pagina_ != 0 and fim_pagina_ == 0 ')[['eid','inicio_pagina','inicio_pagina_','fim_pagina_','ano','quantidade_citacoes','titulo_documento']]
# Out:
#                     eid inicio_pagina inicio_pagina_ fim_pagina_   ano  \
# 230  2-s2.0-73949088594           961            961           0  2008
# 281  2-s2.0-84951920778          1030           1030           0  2015
# 315  2-s2.0-84894346096          1147           1147           0  2013
# 354  2-s2.0-84871998344            22             22           0  2012
# 359  2-s2.0-39049178417          1150           1150           0  2005
# 390  2-s2.0-85040532558          1252           1252           0  2017
# 399  2-s2.0-84901252203           266            266           0  2013
# 403  2-s2.0-56149098476          1136           1136           0  2007
# 453  2-s2.0-73949103021           964            964           0  2008
# 539  2-s2.0-73949125371          1004           1004           0  2008
# 540  2-s2.0-73949125091           923            923           0  2008
#
#      quantidade_citacoes  \
# 230                 10.0
# 281                  6.0
# 315                  4.0
# 354                  3.0
# 359                  3.0
# 390                  2.0
# 399                  2.0
# 403                  2.0
# 453                  1.0
# 539                  NaN
# 540                  NaN
#
#                                                                                                                            titulo_documento
# 230                                                                            Natural language processing to identify adverse drug events.
# 281                            Extraction of Adverse Events from Clinical Documents to Support Decision Making Using Semantic Preprocessing
# 315                                                            Development of a SNOMED CT based national medication decision support system
# 354                 Knowledge-based biomedical word sense disambiguation: An evaluation and application to clinical document classification
# 359                                                                                           MQAF: a medical question-answering framework.
# 390                                                      MetaMap lite in excel: Biomedical named-entity recognition for non-technical users
# 399                                                 Semantic processing to identify adverse drug event information from black box warnings.
# 403                                                                               Mapping terms to UMLS concepts of the same semantic type.
# 453  Standardized documentation in physical therapy: testing of validity and reliability of the PT-ITC and mapping it to the Metathesaurus.
# 539                                                              Computerized surveillance for adverse drug events in a pediatric hospital.
# 540                                            Reporting adverse experiences related to drugs: an ontology-based tool to help the citizens.

# %%
df_scopus.loc[(df_scopus['inicio_pagina_'] != 0) & (df_scopus['fim_pagina_'] == 0),'inicio_pagina_'] = 0

# %%
df_scopus.query('inicio_pagina_ != 0 and fim_pagina_ == 0 ')[['eid','inicio_pagina_','fim_pagina_','ano']]
# Out:
# Empty DataFrame
# Columns: [eid, inicio_pagina_, fim_pagina_, ano]
# Index: []

# %%
df_scopus.query('inicio_pagina_ == 0 and fim_pagina_ != 0 ')[['eid','inicio_pagina','inicio_pagina_','fim_pagina_','ano','quantidade_citacoes','quantidade_paginas','id_pubmed','titulo_documento']]
# Out:
# Empty DataFrame
# Columns: [eid, inicio_pagina, inicio_pagina_, fim_pagina_, ano, quantidade_citacoes, quantidade_paginas, id_pubmed, titulo_documento]
# Index: []

# %% [markdown]
# #### Ajuste de registros com valor 0 - coluna `status_pagina` deve receber `False`
# <br>
# As colunas `inicio_pagina_` e `fim_pagina_` que tiverem o valor 0 (total de 145 rows), devem receber na coluna `status_pagina` o valor de False

# %%
df_scopus.query('inicio_pagina_ == 0 or fim_pagina_ == 0 ')[['eid','inicio_pagina_','fim_pagina_','status_pagina']]
# Out:
#                     eid inicio_pagina_ fim_pagina_  status_pagina
# 11   2-s2.0-85016601538              0           0           True
# 20   2-s2.0-44649165797              0           0           True
# 40   2-s2.0-85112136998              0           0           True
# 44   2-s2.0-85041059362              0           0           True
# 45   2-s2.0-84977543021              0           0           True
# ..                  ...            ...         ...            ...
# 531  2-s2.0-84922021504              0           0           True
# 534  2-s2.0-84922021355              0           0           True
# 538  2-s2.0-70350577030              0           0           True
# 539  2-s2.0-73949125371              0           0           True
# 540  2-s2.0-73949125091              0           0           True
#
# [145 rows x 4 columns]

# %%
df_scopus.loc[(df_scopus['inicio_pagina_'] == 0) | (df_scopus['fim_pagina_'] == 0),'status_pagina'] = False

# %%
df_scopus.query('inicio_pagina_ == 0 or fim_pagina_ == 0 ')[['eid','inicio_pagina_','fim_pagina_','status_pagina']]
# Out:
#                     eid inicio_pagina_ fim_pagina_  status_pagina
# 11   2-s2.0-85016601538              0           0          False
# 20   2-s2.0-44649165797              0           0          False
# 40   2-s2.0-85112136998              0           0          False
# 44   2-s2.0-85041059362              0           0          False
# 45   2-s2.0-84977543021              0           0          False
# ..                  ...            ...         ...            ...
# 531  2-s2.0-84922021504              0           0          False
# 534  2-s2.0-84922021355              0           0          False
# 538  2-s2.0-70350577030              0           0          False
# 539  2-s2.0-73949125371              0           0          False
# 540  2-s2.0-73949125091              0           0          False
#
# [145 rows x 4 columns]

# %% [markdown]
# #### Ajuste de tipagem das colunas para int
# <br>
# As colunas `inicio_pagina_` e `fim_pagina_` são do tipo object, devem ser ajustadas para inteiro

# %%
df_scopus['inicio_pagina_'] = df_scopus['inicio_pagina_'].astype('int')
df_scopus['fim_pagina_'] = df_scopus['fim_pagina_'].astype('int')

# %% [markdown]
# #### Ajustar e contabilizar a coluna `quantidade_paginas`
# <br>
# A coluna `quantidade_paginas` receberá o valor da diferença das colunas `fim_pagina_` e `inicio_pagina_`, é somado + 1, pois deve ser contabilizado o "inlcusive" das páginas citadas. Porém, só pode ser calculados onde a coluna `status_pagina` tenha o valor = True
# <br>
# Exemplo: 477 - 472 = 5, contudo, são 6 páginas e não 5

# %%
# Criar tratamento em que a coluna receberá o valor calculaddo apenas se a coluna `status_pagina` for = True
df_scopus['quantidade_paginas_'] = (1 + (df_scopus['fim_pagina_'] - df_scopus['inicio_pagina_']))

# %%
df_scopus.query('inicio_pagina_ == 0 or fim_pagina_ == 0 ')[['eid','inicio_pagina_','fim_pagina_','quantidade_paginas_','status_pagina']]
# Out:
#                     eid  inicio_pagina_  fim_pagina_  quantidade_paginas_  \
# 122  2-s2.0-33748864015               0            0                    1
# 359  2-s2.0-39049178417               0            0                    1
# 20   2-s2.0-44649165797               0            0                    1
# 403  2-s2.0-56149098476               0            0                    1
# 110  2-s2.0-70349871732               0            0                    1
# ..                  ...             ...          ...                  ...
# 460  2-s2.0-85127196745               0            0                    1
# 459  2-s2.0-85128135291               0            0                    1
# 457  2-s2.0-85129396616               0            0                    1
# 468  2-s2.0-85129630760               0            0                    1
# 455  2-s2.0-85130573183               0            0                    1
#
#      status_pagina
# 122          False
# 359          False
# 20           False
# 403          False
# 110          False
# ..             ...
# 460          False
# 459          False
# 457          False
# 468          False
# 455          False
#
# [143 rows x 5 columns]

# %%
print(df_scopus['inicio_pagina_'].unique())
# Out:
# [ 890  139   17  115  334  529 2059  487  306  161  823    0  589  254
#   674  242  545  839  525  153  621  602  346 2077  328  387  763    1
#    61  687  293  171   91  595  322  536  559  549  902  739  511  671
#   492  354    8  158   92  789  491  206  631  456  794   39  755  217
#   228 1011   25  235  164 1019 1270  435  294   33  609  482 1030 1244
#   997  727  713  882  876  954  914   27   67  227  434   63  296  943
#   682  567  496  113  274  665  592  548  343   60  925  824  152  272
#   191   53   85  196  605  300  777 1065  111  116  702 1013   23   73
#    64  121  170   55  318   15  122  280  268  288  333  539  285  643
#  1779  383  443 1675   95  428  380   37  260  442  467  177   90   18
#    62  148 1075   22  155  103  169 1077  699  523  243  737  581  528
#    51   97  571  150  160  612  396  120  339   72 1057  247  224  813
#   841  984  221  143  190 1945  913 4791  237  522   20   43   79 2022
#   915  614   47  604  149  316  331  552 1154  695  424 1232 4325  661
#   163   89  184  822  405  176  762  573  679  106   96  185 1274 1339
#   391   99   31  123 2790  147  313  189  848  743  216   57  996 1143
#  1414  646  360  615   75  137 1309   45  388  452  420  499 1618  182
#    56   65    3   13 1093 1032 6093  319  258   12 1051 2349  454 1291
#   917  198  775  644 1046   83  423 2922  259 2777  642  126  413   86
#  3015  569  585  638  273  860 2593  706  127  807  307  833 1235 2184
#    49 1207  311  394  104 1605  505  418   87 1105  108 2112  407]

# %%
print(df_scopus['fim_pagina_'].unique())
# Out:
# [ 896  153   21  128  341  533 2066  491  310  166  828    0  599  258
#   678  246  549  844  529  169  629  612  353 2083  337  394  767    5
#    65  691  297  177   96  601  329  539  562  554  913  743  515  326
#   674  496  102  360   12  161  804  497  213  638  461  798   43  684
#   766  226  234  123 1018   32  239  303  168 1026 1279  444  301   42
#   618  488 1039 1253 1003  734  723  886  881  961   29  920   30   74
#   238  443   77  307  947  686  571  500    8  118  280  671  557  350
#    80  937  909  832  164  279  199  359   62   89  207  790  251  681
#  1069  115  120  706 1017   81  217   72  131  174   59  327  332   24
#   132  287  291  349  543  289  647 1788  391  454  733  393 1680  109
#   434  386  265  448  476  181   99   27   76  158   47  264 1079  245
#   110  457  172  362  490 1084  708  530  250   10  592  127   67  104
#   582  178  616  411  125  343 1089 1064  253  233   71  821  993  227
#   149  194 1953   35 4809  248  531   28   11   48   82 2028  101  119
#   924   86   56  610  157  324  336  555 1159   57  402  701   52  427
#  1243 4330  669  170   92  841  410  150  188  192  688  114  100  107
#   196 1283 1350   60  401   36  133 2797  111  156  325  212  870  746
#    51  231   34  171 1000   41   45   70 1151 1426  654  367  141 1317
#    55   64  392  456  446  130  951  510 1626   46   38 1097 1038 6096
#   300   26   18 1060 2359  463 1299  923  202   58  785  652 1056   94
#  2931  268 2786  668  421 3020  577  590  282  869  651 2607  711  137
#   812  237  316  429 1245 2192 1224  314  398  148 1610  514  772 1116
#    53  117 2123  418]

# %% [markdown]
# ### Ajuste de textos de algumas colunas para minúsculo (lower)

# %%
## Passar colunas a serem trabalhadas para lower case
df_scopus["titulo_documento"] = df_scopus["titulo_documento"].str.lower()
df_scopus["resumo"] = df_scopus["resumo"].str.lower()
df_scopus["doi"] = df_scopus["doi"].str.lower()

# %% [markdown]
# ### Remover caracteres especiais

# %%
df_scopus.query('eid == "2-s2.0-73949103021" ')
# Out:
#                                                        autores_scopus  \
# 453  Hardardottir A., Heimisdottir M., Aronson A.R., Gunnarsdottir V.
#
#                                            id_autores  \
# 453  35299380200;35268622200;17933416200;15768914600;
#
#                                                                                                                          titulo_documento  \
# 453  standardized documentation in physical therapy testing of validity and reliability of the pt itc and mapping it to the metathesaurus
#
#       ano  \
# 453  2008
#
#                                                                titulo_fonte  \
# 453  AMIA ... Annual Symposium proceedings / AMIA Symposium. AMIA Symposium
#
#     volume publicado numero_documento inicio_pagina fim_pagina  ...  \
# 453    NaN       NaN              NaN           964        NaN  ...
#
#      etapa_publicacao  acesso_livre   fonte                 eid  doi  \
# 453             Final           NaN  Scopus  2-s2.0-73949103021  NaN
#
#                                                                                                                     titulo_documento_scopus  \
# 453  Standardized documentation in physical therapy: testing of validity and reliability of the PT-ITC and mapping it to the Metathesaurus.
#
#     inicio_pagina_ fim_pagina_ status_pagina  quantidade_paginas_
# 453              0           0         False                    1
#
# [1 rows x 60 columns]

# %%
## Caracateres especiais tem q ficar acima da função limpar
df_scopus["titulo_documento"] = df_scopus["titulo_documento"].apply(lambda x: re.sub('\?|\*|;|,|\.|-|–|:|“|”|"|—|•', ' ', x))

# %%
df_scopus.query('eid == "2-s2.0-73949103021" ')
# Out:
#                                                        autores_scopus  \
# 453  Hardardottir A., Heimisdottir M., Aronson A.R., Gunnarsdottir V.
#
#                                            id_autores  \
# 453  35299380200;35268622200;17933416200;15768914600;
#
#                                                                                                                          titulo_documento  \
# 453  standardized documentation in physical therapy testing of validity and reliability of the pt itc and mapping it to the metathesaurus
#
#       ano  \
# 453  2008
#
#                                                                titulo_fonte  \
# 453  AMIA ... Annual Symposium proceedings / AMIA Symposium. AMIA Symposium
#
#     volume publicado numero_documento inicio_pagina fim_pagina  ...  \
# 453    NaN       NaN              NaN           964        NaN  ...
#
#      etapa_publicacao  acesso_livre   fonte                 eid  doi  \
# 453             Final           NaN  Scopus  2-s2.0-73949103021  NaN
#
#                                                                                                                     titulo_documento_scopus  \
# 453  Standardized documentation in physical therapy: testing of validity and reliability of the PT-ITC and mapping it to the Metathesaurus.
#
#     inicio_pagina_ fim_pagina_ status_pagina  quantidade_paginas_
# 453              0           0         False                    1
#
# [1 rows x 60 columns]

# %%
def limpar_campo(s):
    return re.sub(r'[\u00a0 .M]', ' ', s)

# %%
df_scopus.loc[:,'titulo_documento'] = df_scopus['titulo_documento'].apply(limpar_campo)

# %%
df_scopus['titulo_documento'] = df_scopus['titulo_documento'].str.replace('  ', ' ')

# %%
df_scopus.query('eid == "2-s2.0-73949103021" ')
# Out:
#                                                        autores_scopus  \
# 453  Hardardottir A., Heimisdottir M., Aronson A.R., Gunnarsdottir V.
#
#                                            id_autores  \
# 453  35299380200;35268622200;17933416200;15768914600;
#
#                                                                                                                          titulo_documento  \
# 453  standardized documentation in physical therapy testing of validity and reliability of the pt itc and mapping it to the metathesaurus
#
#       ano  \
# 453  2008
#
#                                                                titulo_fonte  \
# 453  AMIA ... Annual Symposium proceedings / AMIA Symposium. AMIA Symposium
#
#     volume publicado numero_documento inicio_pagina fim_pagina  ...  \
# 453    NaN       NaN              NaN           964        NaN  ...
#
#      etapa_publicacao  acesso_livre   fonte                 eid  doi  \
# 453             Final           NaN  Scopus  2-s2.0-73949103021  NaN
#
#                                                                                                                     titulo_documento_scopus  \
# 453  Standardized documentation in physical therapy: testing of validity and reliability of the PT-ITC and mapping it to the Metathesaurus.
#
#     inicio_pagina_ fim_pagina_ status_pagina  quantidade_paginas_
# 453              0           0         False                    1
#
# [1 rows x 60 columns]

# %% [markdown]
# ### Remoção de espaços de textos de algumas colunas (strip)

# %%
df_scopus["titulo_documento"] = df_scopus["titulo_documento"].str.strip()
df_scopus["resumo"] = df_scopus["resumo"].str.strip()

# %% [markdown]
# ### Ajustar tipagem de dados

# %%
print('Ajustar tipagem dos dados')
df_scopus['fabricantes'] = df_scopus['fabricantes'].astype('category')
df_scopus['acesso_livre'] = df_scopus['acesso_livre'].astype('category')
df_scopus['idioma_original'] = df_scopus['idioma_original'].astype('category')
df_scopus['etapa_publicacao'] = df_scopus['etapa_publicacao'].astype('category')
df_scopus['fonte'] = df_scopus['fonte'].astype('category')
# Out:
# Ajustar tipagem dos dados

# %% [markdown]
# ## Exclusão de documentos

# %% [markdown]
# ### Exclusão de documentos duplicados

# %%
# Ordenando para excluir primeiro as duplicidades
df_scopus = df_scopus.sort_values(['eid','titulo_documento'])
df_scopus[['eid','titulo_documento']]
# Out:
#                     eid  \
# 95    2-s2.0-0026721457
# 129   2-s2.0-0034233257
# 0     2-s2.0-0035752429
# 3     2-s2.0-0037353241
# 63    2-s2.0-0345604428
# ..                  ...
# 457  2-s2.0-85129396616
# 468  2-s2.0-85129630760
# 467  2-s2.0-85129638986
# 456  2-s2.0-85130427489
# 455  2-s2.0-85130573183
#
#                                                                                                                                                titulo_documento
# 95                                                                                development of a questionnaire for detecting potential adverse drug reactions
# 129                            the use of a medical dictionary for regulatory activities terminology (meddra) in prescription event monitoring in japan (j pem)
# 0                                                                            effective mapping of biomedical text to the umls metathesaurus the metamap program
# 3                                                                                                         detecting adverse events using information technology
# 63                                                                          towards linking patients and clinical information detecting umls concepts in e mail
# ..                                                                                                                                                          ...
# 457  identification of hand foot syndrome from cancer patients’ blog posts bert based deep learning approach to detect potential adverse drug reaction symptoms
# 468                                              antipsychotic polypharmacy and adverse drug reactions among adults in a london mental health service 2008 2018
# 467                                                                      on the road to explainable ai in drug drug interactions prediction a systematic review
# 456                                                 artificial intelligence in pharmacovigilance an introduction to terms concepts applications and limitations
# 455                                           monitoring user opinions and side effects on covid 19 vaccines in the twittersphere infodemiology study of tweets
#
# [523 rows x 2 columns]

# %%
# 4 documentos duplicados
print("Verifica se a coluna em destaque tem duplicados, aparecendo a qtd na direita")
df_scopus.titulo_documento.value_counts()
# Out:
# Verifica se a coluna em destaque tem duplicados, aparecendo a qtd na direita
# development of a questionnaire for detecting potential adverse drug reactions                                                1
# a proficient spelling analysis method applied to a pharmacovigilance task                                                    1
# initial experiments for pharmacovigilance analysis in social media using summaries of product characteristics                1
# assessment of word embedding techniques for identification of personal experience tweets pertaining to medication uses       1
# comparison of text processing methods in social media based signal detection                                                 1
#                                                                                                                             ..
# identifying diseases drugs and symptoms in twitter                                                                           1
# initiate an intelligent adaptive alert environment                                                                           1
# assessing the need of discourse level analysis in identifying evidence of drug disease relations in scientific literature    1
# extraction of adverse events from clinical documents to support decision making using semantic preprocessing                 1
# monitoring user opinions and side effects on covid 19 vaccines in the twittersphere infodemiology study of tweets            1
# Name: titulo_documento, Length: 523, dtype: int64

# %%
df_scopus.query('titulo_documento == "implementing public health analytical services grid enabling of metamap" ')[['eid','id_pubmed','status_pagina','titulo_documento']]
# Out:
#                     eid  id_pubmed  status_pagina  \
# 533  2-s2.0-84897097034        NaN           True
#
#                                                             titulo_documento
# 533  implementing public health analytical services grid enabling of metamap

# %%
## o last exclui a primeira ocorrencia e ou, fica apenas com a última ocorrência
df_scopus = df_scopus.drop_duplicates(['titulo_documento','autores_scopus'], keep='last') ## de 541 para [537 rows x 59 columns]
print(df_scopus)
# Out:
#                                                                                                        autores_scopus  \
# 95                                                       Corso D.M., Pucino F., DeLeo J.M., Calis K.A., Gallelli J.F.
# 129                                                                                Yokotsuka M., Aoyama M., Kubota K.
# 0                                                                                                        Aronson A.R.
# 3                                         Bates D.W., Evans R.S., Murff H., Stetson P.D., Pizzifferri L., Hripcsak G.
# 63                                                                                         Brennan P.F., Aronson A.R.
# ..                                                                                                                ...
# 457  Nishioka S., Watanabe T., Asano M., Yamamoto T., Kawakami K., Yada S., Aramaki E., Yajima H., Kizaki H., Hori S.
# 468                                                 Yang J.C., Thygesen J.H., Werbeloff N., Hayes J.F., Osborn D.P.J.
# 467                                                                       Vo T.H., Nguyen N.T.K., Kha Q.H., Le N.Q.K.
# 456                                                                                                      Aronson J.K.
# 455                                              Portelli B., Scaboro S., Tonino R., Chersoni E., Santus E., Serra G.
#
#                                                                                                                   id_autores  \
# 95                                                                 6602576929;6701705695;35579441300;57221571096;7003762821;
# 129                                                                                       6505861090;7202591218;24356074400;
# 0                                                                                                               17933416200;
# 3                                                        57113031900;7405652324;6701719661;7005833624;6508207735;7004471151;
# 63                                                                                                  35473309900;17933416200;
# ..                                                                                                                       ...
# 457  57665231500;57665866200;57666183300;57666504400;36484772100;57219665421;57203225161;57665866300;57607977600;8058209600;
# 468                                                              57202692614;42162169300;25522505100;36518630100;7101639320;
# 467                                                                         57671574900;57211071169;57224131231;57208281644;
# 456                                                                                                             55683060600;
# 455                                                 57219796263;57274686400;57704816900;57193697675;57189268006;10140344600;
#
#                                                                                                                                                titulo_documento  \
# 95                                                                                development of a questionnaire for detecting potential adverse drug reactions
# 129                            the use of a medical dictionary for regulatory activities terminology (meddra) in prescription event monitoring in japan (j pem)
# 0                                                                            effective mapping of biomedical text to the umls metathesaurus the metamap program
# 3                                                                                                         detecting adverse events using information technology
# 63                                                                          towards linking patients and clinical information detecting umls concepts in e mail
# ..                                                                                                                                                          ...
# 457  identification of hand foot syndrome from cancer patients’ blog posts bert based deep learning approach to detect potential adverse drug reaction symptoms
# 468                                              antipsychotic polypharmacy and adverse drug reactions among adults in a london mental health service 2008 2018
# 467                                                                      on the road to explainable ai in drug drug interactions prediction a systematic review
# 456                                                 artificial intelligence in pharmacovigilance an introduction to terms concepts applications and limitations
# 455                                           monitoring user opinions and side effects on covid 19 vaccines in the twittersphere infodemiology study of tweets
#
#       ano                                             titulo_fonte volume  \
# 95   1992                                Annals of Pharmacotherapy     26
# 129  2000             International Journal of Medical Informatics     57
# 0    2001  Proceedings / AMIA ... Annual Symposium. AMIA Symposium    NaN
# 3    2003  Journal of the American Medical Informatics Association     10
# 63   2003                        Journal of Biomedical Informatics     36
# ..    ...                                                      ...    ...
# 457  2022                                                 PLoS ONE     17
# 468  2022                                   Psychological Medicine    NaN
# 467  2022       Computational and Structural Biotechnology Journal     20
# 456  2022                                              Drug Safety     45
# 455  2022                     Journal of Medical Internet Research     24
#
#     publicado numero_documento inicio_pagina fim_pagina  ...  \
# 95        7-8              NaN           890        896  ...
# 129       2-3              NaN           139        153  ...
# 0         NaN              NaN            17         21  ...
# 3           2              NaN           115        128  ...
# 63        4-5              NaN           334        341  ...
# ..        ...              ...           ...        ...  ...
# 457     5 May         e0267901           NaN        NaN  ...
# 468       NaN              NaN           NaN        NaN  ...
# 467       NaN              NaN          2112       2123  ...
# 456         5              NaN           407        418  ...
# 455         5           e35115           NaN        NaN  ...
#
#      etapa_publicacao                    acesso_livre   fonte  \
# 95              Final                             NaN  Scopus
# 129             Final                             NaN  Scopus
# 0               Final                             NaN  Scopus
# 3               Final  All Open Access, Bronze, Green  Scopus
# 63              Final         All Open Access, Bronze  Scopus
# ..                ...                             ...     ...
# 457             Final    All Open Access, Gold, Green  Scopus
# 468  Article in Press          All Open Access, Green  Scopus
# 467             Final           All Open Access, Gold  Scopus
# 456             Final                             NaN  Scopus
# 455             Final    All Open Access, Gold, Green  Scopus
#
#                     eid                            doi  \
# 95    2-s2.0-0026721457     10.1177/106002809202600704
# 129   2-s2.0-0034233257  10.1016/s1386-5056(00)00062-9
# 0     2-s2.0-0035752429                            NaN
# 3     2-s2.0-0037353241            10.1197/jamia.m1074
# 63    2-s2.0-0345604428      10.1016/j.jbi.2003.09.017
# ..                  ...                            ...
# 457  2-s2.0-85129396616   10.1371/journal.pone.0267901
# 468  2-s2.0-85129630760      10.1017/s0033291722000952
# 467  2-s2.0-85129638986     10.1016/j.csbj.2022.04.021
# 456  2-s2.0-85130427489     10.1007/s40264-022-01156-5
# 455  2-s2.0-85130573183                  10.2196/35115
#
#                                                                                                                                          titulo_documento_scopus  \
# 95                                                                                 Development of a questionnaire for detecting potential adverse drug reactions
# 129                             The use of a medical dictionary for regulatory activities terminology (MedDRA) in prescription-event monitoring in Japan (J-PEM)
# 0                                                                           Effective mapping of biomedical text to the UMLS Metathesaurus: the MetaMap program.
# 3                                                                                                          Detecting adverse events using information technology
# 63                                                                          Towards linking patients and clinical information: Detecting UMLS concepts in e-mail
# ..                                                                                                                                                           ...
# 457  Identification of hand-foot syndrome from cancer patients’ blog posts: BERT-based deep-learning approach to detect potential adverse drug reaction symptoms
# 468                                              Antipsychotic polypharmacy and adverse drug reactions among adults in a London mental health service, 2008-2018
# 467                                                                      On the road to explainable AI in drug-drug interactions prediction: A systematic review
# 456                                              Artificial Intelligence in Pharmacovigilance: An Introduction to Terms, Concepts, Applications, and Limitations
# 455                                           Monitoring User Opinions and Side Effects on COVID-19 Vaccines in the Twittersphere: Infodemiology Study of Tweets
#
#     inicio_pagina_ fim_pagina_ status_pagina  quantidade_paginas_
# 95             890         896          True                    7
# 129            139         153          True                   15
# 0               17          21          True                    5
# 3              115         128          True                   14
# 63             334         341          True                    8
# ..             ...         ...           ...                  ...
# 457              0           0         False                    1
# 468              0           0         False                    1
# 467           2112        2123          True                   12
# 456            407         418          True                   12
# 455              0           0         False                    1
#
# [523 rows x 60 columns]

# %%
## artigo estranho, parece que repetiu mesmo na base, um tem mais informaçoes que o outro
df_scopus.query('titulo_documento == "implementing public health analytical services grid enabling of metamap" ')[['eid','id_pubmed','titulo_documento']]
# Out:
#                     eid  id_pubmed  \
# 533  2-s2.0-84897097034        NaN
#
#                                                             titulo_documento
# 533  implementing public health analytical services grid enabling of metamap

# %% [markdown]
# ### Exclusão de documentos com menos de 4 páginas (3 páginas para baixo)
# <br> Antes do tratamento em `páginas` eram excluídos 33, agora são 14 para ser excluídos
# <br> Analisado 4 casos dos 14 e bate ok ... **77 verificar se na hora de exclusãso de registros vai estar ok

# %%
# 14 registros
df_scopus.query('quantidade_paginas_ <= 3 and status_pagina == True ')[['eid','ano','inicio_pagina_','quantidade_paginas_','status_pagina','titulo_documento']]
# Out:
# Empty DataFrame
# Columns: [eid, ano, inicio_pagina_, quantidade_paginas_, status_pagina, titulo_documento]
# Index: []

# %%
#523 rows × 60 columns
df_remove_page3 = df_scopus.loc[
    ((df_scopus['status_pagina'] == True) & (df_scopus['quantidade_paginas_'] <= 3))
]

df_remove_page3

df_scopus = df_scopus.drop(df_remove_page3.index)
df_scopus
# Out:
#                                                                                                        autores_scopus  \
# 95                                                       Corso D.M., Pucino F., DeLeo J.M., Calis K.A., Gallelli J.F.
# 129                                                                                Yokotsuka M., Aoyama M., Kubota K.
# 0                                                                                                        Aronson A.R.
# 3                                         Bates D.W., Evans R.S., Murff H., Stetson P.D., Pizzifferri L., Hripcsak G.
# 63                                                                                         Brennan P.F., Aronson A.R.
# ..                                                                                                                ...
# 457  Nishioka S., Watanabe T., Asano M., Yamamoto T., Kawakami K., Yada S., Aramaki E., Yajima H., Kizaki H., Hori S.
# 468                                                 Yang J.C., Thygesen J.H., Werbeloff N., Hayes J.F., Osborn D.P.J.
# 467                                                                       Vo T.H., Nguyen N.T.K., Kha Q.H., Le N.Q.K.
# 456                                                                                                      Aronson J.K.
# 455                                              Portelli B., Scaboro S., Tonino R., Chersoni E., Santus E., Serra G.
#
#                                                                                                                   id_autores  \
# 95                                                                 6602576929;6701705695;35579441300;57221571096;7003762821;
# 129                                                                                       6505861090;7202591218;24356074400;
# 0                                                                                                               17933416200;
# 3                                                        57113031900;7405652324;6701719661;7005833624;6508207735;7004471151;
# 63                                                                                                  35473309900;17933416200;
# ..                                                                                                                       ...
# 457  57665231500;57665866200;57666183300;57666504400;36484772100;57219665421;57203225161;57665866300;57607977600;8058209600;
# 468                                                              57202692614;42162169300;25522505100;36518630100;7101639320;
# 467                                                                         57671574900;57211071169;57224131231;57208281644;
# 456                                                                                                             55683060600;
# 455                                                 57219796263;57274686400;57704816900;57193697675;57189268006;10140344600;
#
#                                                                                                                                                titulo_documento  \
# 95                                                                                development of a questionnaire for detecting potential adverse drug reactions
# 129                            the use of a medical dictionary for regulatory activities terminology (meddra) in prescription event monitoring in japan (j pem)
# 0                                                                            effective mapping of biomedical text to the umls metathesaurus the metamap program
# 3                                                                                                         detecting adverse events using information technology
# 63                                                                          towards linking patients and clinical information detecting umls concepts in e mail
# ..                                                                                                                                                          ...
# 457  identification of hand foot syndrome from cancer patients’ blog posts bert based deep learning approach to detect potential adverse drug reaction symptoms
# 468                                              antipsychotic polypharmacy and adverse drug reactions among adults in a london mental health service 2008 2018
# 467                                                                      on the road to explainable ai in drug drug interactions prediction a systematic review
# 456                                                 artificial intelligence in pharmacovigilance an introduction to terms concepts applications and limitations
# 455                                           monitoring user opinions and side effects on covid 19 vaccines in the twittersphere infodemiology study of tweets
#
#       ano                                             titulo_fonte volume  \
# 95   1992                                Annals of Pharmacotherapy     26
# 129  2000             International Journal of Medical Informatics     57
# 0    2001  Proceedings / AMIA ... Annual Symposium. AMIA Symposium    NaN
# 3    2003  Journal of the American Medical Informatics Association     10
# 63   2003                        Journal of Biomedical Informatics     36
# ..    ...                                                      ...    ...
# 457  2022                                                 PLoS ONE     17
# 468  2022                                   Psychological Medicine    NaN
# 467  2022       Computational and Structural Biotechnology Journal     20
# 456  2022                                              Drug Safety     45
# 455  2022                     Journal of Medical Internet Research     24
#
#     publicado numero_documento inicio_pagina fim_pagina  ...  \
# 95        7-8              NaN           890        896  ...
# 129       2-3              NaN           139        153  ...
# 0         NaN              NaN            17         21  ...
# 3           2              NaN           115        128  ...
# 63        4-5              NaN           334        341  ...
# ..        ...              ...           ...        ...  ...
# 457     5 May         e0267901           NaN        NaN  ...
# 468       NaN              NaN           NaN        NaN  ...
# 467       NaN              NaN          2112       2123  ...
# 456         5              NaN           407        418  ...
# 455         5           e35115           NaN        NaN  ...
#
#      etapa_publicacao                    acesso_livre   fonte  \
# 95              Final                             NaN  Scopus
# 129             Final                             NaN  Scopus
# 0               Final                             NaN  Scopus
# 3               Final  All Open Access, Bronze, Green  Scopus
# 63              Final         All Open Access, Bronze  Scopus
# ..                ...                             ...     ...
# 457             Final    All Open Access, Gold, Green  Scopus
# 468  Article in Press          All Open Access, Green  Scopus
# 467             Final           All Open Access, Gold  Scopus
# 456             Final                             NaN  Scopus
# 455             Final    All Open Access, Gold, Green  Scopus
#
#                     eid                            doi  \
# 95    2-s2.0-0026721457     10.1177/106002809202600704
# 129   2-s2.0-0034233257  10.1016/s1386-5056(00)00062-9
# 0     2-s2.0-0035752429                            NaN
# 3     2-s2.0-0037353241            10.1197/jamia.m1074
# 63    2-s2.0-0345604428      10.1016/j.jbi.2003.09.017
# ..                  ...                            ...
# 457  2-s2.0-85129396616   10.1371/journal.pone.0267901
# 468  2-s2.0-85129630760      10.1017/s0033291722000952
# 467  2-s2.0-85129638986     10.1016/j.csbj.2022.04.021
# 456  2-s2.0-85130427489     10.1007/s40264-022-01156-5
# 455  2-s2.0-85130573183                  10.2196/35115
#
#                                                                                                                                          titulo_documento_scopus  \
# 95                                                                                 Development of a questionnaire for detecting potential adverse drug reactions
# 129                             The use of a medical dictionary for regulatory activities terminology (MedDRA) in prescription-event monitoring in Japan (J-PEM)
# 0                                                                           Effective mapping of biomedical text to the UMLS Metathesaurus: the MetaMap program.
# 3                                                                                                          Detecting adverse events using information technology
# 63                                                                          Towards linking patients and clinical information: Detecting UMLS concepts in e-mail
# ..                                                                                                                                                           ...
# 457  Identification of hand-foot syndrome from cancer patients’ blog posts: BERT-based deep-learning approach to detect potential adverse drug reaction symptoms
# 468                                              Antipsychotic polypharmacy and adverse drug reactions among adults in a London mental health service, 2008-2018
# 467                                                                      On the road to explainable AI in drug-drug interactions prediction: A systematic review
# 456                                              Artificial Intelligence in Pharmacovigilance: An Introduction to Terms, Concepts, Applications, and Limitations
# 455                                           Monitoring User Opinions and Side Effects on COVID-19 Vaccines in the Twittersphere: Infodemiology Study of Tweets
#
#     inicio_pagina_ fim_pagina_ status_pagina  quantidade_paginas_
# 95             890         896          True                    7
# 129            139         153          True                   15
# 0               17          21          True                    5
# 3              115         128          True                   14
# 63             334         341          True                    8
# ..             ...         ...           ...                  ...
# 457              0           0         False                    1
# 468              0           0         False                    1
# 467           2112        2123          True                   12
# 456            407         418          True                   12
# 455              0           0         False                    1
#
# [523 rows x 60 columns]

# %%
## estes entrarão para leitura
df_scopus.query('quantidade_paginas_ <= 3 ')[['eid','ano','inicio_pagina_','fim_pagina_','quantidade_paginas_','status_pagina','titulo_documento']]
# Out:
#                     eid   ano  inicio_pagina_  fim_pagina_  \
# 122  2-s2.0-33748864015  2006               0            0
# 359  2-s2.0-39049178417  2005               0            0
# 20   2-s2.0-44649165797  2008               0            0
# 403  2-s2.0-56149098476  2007               0            0
# 110  2-s2.0-70349871732  2009               0            0
# ..                  ...   ...             ...          ...
# 460  2-s2.0-85127196745  2022               0            0
# 459  2-s2.0-85128135291  2022               0            0
# 457  2-s2.0-85129396616  2022               0            0
# 468  2-s2.0-85129630760  2022               0            0
# 455  2-s2.0-85130573183  2022               0            0
#
#      quantidade_paginas_  status_pagina  \
# 122                    1          False
# 359                    1          False
# 20                     1          False
# 403                    1          False
# 110                    1          False
# ..                   ...            ...
# 460                    1          False
# 459                    1          False
# 457                    1          False
# 468                    1          False
# 455                    1          False
#
#                                                                                                                                                titulo_documento
# 122                               argument predicate distance as a filter for enhancing precision in extracting predications on the genetic etiology of disease
# 359                                                                                                                 mqaf a medical question answering framework
# 20                                                                            assessment of disease named entity recognition on a corpus of annotated sentences
# 403                                                                                                    mapping terms to umls concepts of the same semantic type
# 110                                             characterizing environmental and phenotypic associations using information theory and electronic health records
# ..                                                                                                                                                          ...
# 460                                               using natural language processing techniques to detect adverse events from progress notes due to chemotherapy
# 459     using named entity recognition to identify substances used in the self medication of opioid withdrawal natural language processing study of reddit data
# 457  identification of hand foot syndrome from cancer patients’ blog posts bert based deep learning approach to detect potential adverse drug reaction symptoms
# 468                                              antipsychotic polypharmacy and adverse drug reactions among adults in a london mental health service 2008 2018
# 455                                           monitoring user opinions and side effects on covid 19 vaccines in the twittersphere infodemiology study of tweets
#
# [143 rows x 7 columns]

# %% [markdown]
# ## Reanálise do dataframe

# %%
print('Verificando tipos e se tem dados nulos')
df_scopus.info()
# Out:
# Verificando tipos e se tem dados nulos
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 523 entries, 95 to 455
# Data columns (total 60 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   autores_scopus               523 non-null    object
#  1   id_autores                   523 non-null    object
#  2   titulo_documento             523 non-null    object
#  3   ano                          523 non-null    int64
#  4   titulo_fonte                 523 non-null    object
#  5   volume                       445 non-null    object
#  6   publicado                    227 non-null    object
#  7   numero_documento             141 non-null    object
#  8   inicio_pagina                389 non-null    object
#  9   fim_pagina                   380 non-null    object
#  10  quantidade_paginas           3 non-null      float64
#  11  quantidade_citacoes          445 non-null    float64
#  12  doi_scopus                   427 non-null    object
#  13  link_scopus                  523 non-null    object
#  14  afiliacoes                   519 non-null    object
#  15  autores_com_filiacoes        520 non-null    object
#  16  resumo                       523 non-null    object
#  17  palavras_chaves_autor        367 non-null    object
#  18  palavras_chave_index         474 non-null    object
#  19  numeros_sequencia_molecular  0 non-null      float64
#  20  chemicals_cas                116 non-null    object
#  21  nomes_comerciais             20 non-null     object
#  22  fabricantes                  2 non-null      category
#  23  detalhes_financiamento       268 non-null    object
#  24  texto_financiamento_1        243 non-null    object
#  25  texto_financiamento_2        27 non-null     object
#  26  texto_financiamento_3        3 non-null      object
#  27  texto_financiamento_4        0 non-null      float64
#  28  texto_financiamento_5        0 non-null      float64
#  29  texto_financiamento_6        0 non-null      float64
#  30  texto_financiamento_7        0 non-null      float64
#  31  texto_financiamento_8        0 non-null      float64
#  32  texto_financiamento_9        0 non-null      float64
#  33  texto_financiamento_10       0 non-null      float64
#  34  referencias                  466 non-null    object
#  35  endereco_correspondencia     417 non-null    object
#  36  editores                     92 non-null     object
#  37  patrocinadores               47 non-null     object
#  38  editor                       423 non-null    object
#  39  nome_conferencia             155 non-null    object
#  40  data_conferencia             155 non-null    object
#  41  local_conferencia            29 non-null     object
#  42  codigo_conferencia           144 non-null    float64
#  43  issn_scopus                  457 non-null    object
#  44  isbn                         130 non-null    object
#  45  coden                        192 non-null    object
#  46  id_pubmed                    320 non-null    float64
#  47  idioma_original              523 non-null    category
#  48  titulo_abreviado_fonte       522 non-null    object
#  49  tipo_documento               523 non-null    object
#  50  etapa_publicacao             523 non-null    category
#  51  acesso_livre                 255 non-null    category
#  52  fonte                        523 non-null    category
#  53  eid                          523 non-null    object
#  54  doi                          427 non-null    object
#  55  titulo_documento_scopus      523 non-null    object
#  56  inicio_pagina_               523 non-null    int32
#  57  fim_pagina_                  523 non-null    int32
#  58  status_pagina                523 non-null    bool
#  59  quantidade_paginas_          523 non-null    int32
# dtypes: bool(1), category(5), float64(12), int32(3), int64(1), object(38)
# memory usage: 222.5+ KB

# %%
df_scopus.nunique()
# Out:
# autores_scopus                 512
# id_autores                     508
# titulo_documento               523
# ano                             23
# titulo_fonte                   187
# volume                         187
# publicado                       35
# numero_documento               138
# inicio_pagina                  304
# fim_pagina                     314
# quantidade_paginas               3
# quantidade_citacoes             81
# doi_scopus                     427
# link_scopus                    523
# afiliacoes                     512
# autores_com_filiacoes          520
# resumo                         521
# palavras_chaves_autor          367
# palavras_chave_index           474
# numeros_sequencia_molecular      0
# chemicals_cas                   84
# nomes_comerciais                18
# fabricantes                      2
# detalhes_financiamento         254
# texto_financiamento_1          242
# texto_financiamento_2           27
# texto_financiamento_3            3
# texto_financiamento_4            0
# texto_financiamento_5            0
# texto_financiamento_6            0
# texto_financiamento_7            0
# texto_financiamento_8            0
# texto_financiamento_9            0
# texto_financiamento_10           0
# referencias                    466
# endereco_correspondencia       405
# editores                        66
# patrocinadores                  42
# editor                          73
# nome_conferencia               122
# data_conferencia               121
# local_conferencia               24
# codigo_conferencia             115
# issn_scopus                    130
# isbn                           103
# coden                           47
# id_pubmed                      320
# idioma_original                  3
# titulo_abreviado_fonte         183
# tipo_documento                   8
# etapa_publicacao                 2
# acesso_livre                     7
# fonte                            1
# eid                            523
# doi                            427
# titulo_documento_scopus        523
# inicio_pagina_                 293
# fim_pagina_                    312
# status_pagina                    2
# quantidade_paginas_             25
# dtype: int64

# %%
df_scopus.isnull().sum()
# Out:
# autores_scopus                   0
# id_autores                       0
# titulo_documento                 0
# ano                              0
# titulo_fonte                     0
# volume                          78
# publicado                      296
# numero_documento               382
# inicio_pagina                  134
# fim_pagina                     143
# quantidade_paginas             520
# quantidade_citacoes             78
# doi_scopus                      96
# link_scopus                      0
# afiliacoes                       4
# autores_com_filiacoes            3
# resumo                           0
# palavras_chaves_autor          156
# palavras_chave_index            49
# numeros_sequencia_molecular    523
# chemicals_cas                  407
# nomes_comerciais               503
# fabricantes                    521
# detalhes_financiamento         255
# texto_financiamento_1          280
# texto_financiamento_2          496
# texto_financiamento_3          520
# texto_financiamento_4          523
# texto_financiamento_5          523
# texto_financiamento_6          523
# texto_financiamento_7          523
# texto_financiamento_8          523
# texto_financiamento_9          523
# texto_financiamento_10         523
# referencias                     57
# endereco_correspondencia       106
# editores                       431
# patrocinadores                 476
# editor                         100
# nome_conferencia               368
# data_conferencia               368
# local_conferencia              494
# codigo_conferencia             379
# issn_scopus                     66
# isbn                           393
# coden                          331
# id_pubmed                      203
# idioma_original                  0
# titulo_abreviado_fonte           1
# tipo_documento                   0
# etapa_publicacao                 0
# acesso_livre                   268
# fonte                            0
# eid                              0
# doi                             96
# titulo_documento_scopus          0
# inicio_pagina_                   0
# fim_pagina_                      0
# status_pagina                    0
# quantidade_paginas_              0
# dtype: int64

# %%
print('Resumo Estatístico de Campos Numéricos')
#df_scopus.describe()
df_scopus[['ano','quantidade_citacoes','inicio_pagina_','fim_pagina_','quantidade_paginas_' ]].describe()
# Out:
# Resumo Estatístico de Campos Numéricos
#                ano  quantidade_paginas  quantidade_citacoes  inicio_pagina_  \
# count   523.000000            3.000000           445.000000      523.000000
# mean   2016.147228          651.000000            25.269663      365.108987
# std       4.474633          762.055772            75.440622      598.634466
# min    1992.000000           11.000000             1.000000        0.000000
# 25%    2014.000000          229.500000             3.000000        0.000000
# 50%    2017.000000          448.000000            10.000000      147.000000
# 75%    2020.000000          971.000000            25.000000      529.000000
# max    2022.000000         1494.000000          1339.000000     6093.000000
#
#        fim_pagina_  quantidade_paginas_
# count   523.000000           523.000000
# mean    371.600382             7.491396
# std     599.656737            13.441138
# min       0.000000             1.000000
# 25%       0.000000             1.000000
# 50%     157.000000             7.000000
# 75%     536.000000            10.000000
# max    6096.000000           264.000000

# %% [markdown]
# ### Analisar casos abaixo com resultados do resumo estatístico ****

# %%
## qtde de citações
## de fato (Effective mapping of biomedical text to the UMLS Metathesaurus: the MetaMap program.),
# tem mais de 1000 citacoes
df_scopus.query('quantidade_citacoes > 1000 ')[['eid','quantidade_citacoes','quantidade_paginas_','id_pubmed','titulo_documento']]
# Out:
#                  eid  quantidade_citacoes  quantidade_paginas_   id_pubmed  \
# 0  2-s2.0-0035752429               1339.0                    5  11825149.0
#
#                                                                      titulo_documento
# 0  effective mapping of biomedical text to the umls metathesaurus the metamap program

# %%
## qtd de páginas
## de fato (Studies in Health Technology and Informatics), é o livro com todo o conteúdo da conferencia
df_scopus.query('quantidade_paginas > 1000 ')[['eid','ano','quantidade_citacoes','quantidade_paginas','quantidade_paginas_','id_pubmed','titulo_documento','titulo_documento_scopus']]
# Out:
#                     eid   ano  quantidade_citacoes  quantidade_paginas  \
# 503  2-s2.0-85087746524  2020                  NaN              1494.0
#
#      quantidade_paginas_  id_pubmed  \
# 503                    1        NaN
#
#                                  titulo_documento  \
# 503  studies in health technology and informatics
#
#                           titulo_documento_scopus
# 503  Studies in Health Technology and Informatics

# %%
## https://www-sciencedirect.ez108.periodicos.capes.gov.br/science/article/abs/pii/S2213219816306699?via%3Dihub
## Adverse and Hypersensitivity Reactions to Prescription Nonsteroidal Anti-Inflammatory Agents in a Large Health Care System
## dados do documento acima sobre página está errado, deve ter sido informado errado ops, o tratamento no campo nao funcionou
df_scopus.query('quantidade_paginas_ > 1000 ')[['eid','inicio_pagina','fim_pagina','ano','quantidade_citacoes','quantidade_paginas','quantidade_paginas_','id_pubmed','titulo_documento']]
# Out:
# Empty DataFrame
# Columns: [eid, inicio_pagina, fim_pagina, ano, quantidade_citacoes, quantidade_paginas, quantidade_paginas_, id_pubmed, titulo_documento]
# Index: []

# %%
## de 5 casos analisados, sao de fato pequenos, mas tinha um com 4 páginas
# https://ieeexplore-ieee-org.ez108.periodicos.capes.gov.br/stamp/stamp.jsp?tp=&arnumber=9669475 (analisar este com Metamap)
df_scopus.query('quantidade_paginas_ <= 3 ')[['eid','ano','inicio_pagina','fim_pagina','quantidade_citacoes','quantidade_paginas_','titulo_documento']]
# Out:
#                     eid   ano inicio_pagina fim_pagina  quantidade_citacoes  \
# 122  2-s2.0-33748864015  2006           NaN        NaN                 23.0
# 359  2-s2.0-39049178417  2005          1150        NaN                  3.0
# 20   2-s2.0-44649165797  2008           NaN        NaN                 92.0
# 403  2-s2.0-56149098476  2007          1136        NaN                  2.0
# 110  2-s2.0-70349871732  2009           NaN        NaN                 26.0
# ..                  ...   ...           ...        ...                  ...
# 460  2-s2.0-85127196745  2022           NaN        NaN                  NaN
# 459  2-s2.0-85128135291  2022           NaN        NaN                  NaN
# 457  2-s2.0-85129396616  2022           NaN        NaN                  NaN
# 468  2-s2.0-85129630760  2022           NaN        NaN                  NaN
# 455  2-s2.0-85130573183  2022           NaN        NaN                  NaN
#
#      quantidade_paginas_  \
# 122                    1
# 359                    1
# 20                     1
# 403                    1
# 110                    1
# ..                   ...
# 460                    1
# 459                    1
# 457                    1
# 468                    1
# 455                    1
#
#                                                                                                                                                titulo_documento
# 122                               argument predicate distance as a filter for enhancing precision in extracting predications on the genetic etiology of disease
# 359                                                                                                                 mqaf a medical question answering framework
# 20                                                                            assessment of disease named entity recognition on a corpus of annotated sentences
# 403                                                                                                    mapping terms to umls concepts of the same semantic type
# 110                                             characterizing environmental and phenotypic associations using information theory and electronic health records
# ..                                                                                                                                                          ...
# 460                                               using natural language processing techniques to detect adverse events from progress notes due to chemotherapy
# 459     using named entity recognition to identify substances used in the self medication of opioid withdrawal natural language processing study of reddit data
# 457  identification of hand foot syndrome from cancer patients’ blog posts bert based deep learning approach to detect potential adverse drug reaction symptoms
# 468                                              antipsychotic polypharmacy and adverse drug reactions among adults in a london mental health service 2008 2018
# 455                                           monitoring user opinions and side effects on covid 19 vaccines in the twittersphere infodemiology study of tweets
#
# [143 rows x 7 columns]

# %% [markdown]
# ## Visualização

# %% [markdown]
# ### Analisando tipos de acessos dos arquivos

# %%
## pegar os 10 + patrocinadores
df_scopus.acesso_livre.unique()

# %%
# Groupby by
acesso_livre = df_scopus.groupby("acesso_livre")

# Summary statistic of all
acesso_livre.describe()

# %%
# pegar as 10 +
plt.figure(figsize=(15,10))
acesso_livre.size().sort_values(ascending=False).plot.bar()
plt.xticks(rotation=50)
plt.xlabel("Tipos de acesso aos documentos")
plt.ylabel("Quantidade de Documentos")
plt.show()

# %% [markdown]
# ### Analisando tipos de documentos

# %%
# Analisando tipos de documentos
# Groupby by
tipo_documento = df_scopus.groupby("tipo_documento")

# Summary statistic of all
tipo_documento.describe()

# %%
# pegar as 10 +
plt.figure(figsize=(15,10))
tipo_documento.size().sort_values(ascending=False).plot.bar()
plt.xticks(rotation=50)
plt.xlabel("Tipos de documento")
plt.ylabel("Quantidade de documento")
plt.show()

# %% [markdown]
# ### Analisando Locais de Conferencia

# %%
# Groupby by
local_conferencia = df_scopus.groupby("local_conferencia")

# Summary statistic of all
local_conferencia.describe()

# %%
# pegar as 10 +
plt.figure(figsize=(15,10))
local_conferencia.size().sort_values(ascending=False).plot.bar()
plt.xticks(rotation=50)
plt.xlabel("Locais de Conferências")
plt.ylabel("Quantidade")
plt.show()

# %% [markdown]
# ### Analisando Editores

# %%
# Groupby by
editor = df_scopus.groupby("editor")

# Summary statistic of all
editor.describe()

# %%
plt.figure(figsize=(15,10))
editor.size().sort_values(ascending=False).plot.bar()
plt.xticks(rotation=50)
plt.xlabel("Editores")
plt.ylabel("Quantidade de documentos")

# %% [markdown]
# ### Analisando documentos por Ano

# %%
# Groupby by
ano = df_scopus.groupby("ano")

# Summary statistic of all
ano.describe()

# %%
## Ordenar por ano
plt.figure(figsize=(15,10))
ano.size().sort_values(ascending=False).plot.bar()
plt.xticks(rotation=50)
plt.xlabel("Anos")
plt.ylabel("Número de Documentos")
plt.show()

# %% [markdown]
# ### Analisando os idiomas

# %%
# Groupby by
idioma = df_scopus.groupby("idioma_original")

# Summary statistic of all
idioma.describe().head()

# %%
plt.figure(figsize=(15,10))
idioma.size().sort_values(ascending=False).plot.bar()
plt.xticks(rotation=50)
plt.xlabel("Idioma Original")
plt.ylabel("Número de Documentos")
plt.show()

# %% [markdown]
# ### Criar uma visão da quantidade de documentos agrupados por quantidade de páginas + o total de páginas

# %%
## criar

# %% [markdown]
# ### Seaborn - colunas x colunas

# %%
print('Visão geral em gráfico')
sns.pairplot(df_scopus)

# %% [markdown]
#  ### Nuvem de Palavras

# %% [markdown]
# #### Nuvem de Palavras dos Títulos

# %%
stopwords = nltk.corpus.stopwords.words('english')
print(stopwords)

# %%
print('Carregar novo dataframe de palavras apenas com dados da coluna texto, ou seja, uma série.')
palavras_titulo = df_scopus['titulo_documento'].str.lower()
palavras_titulo

# %%
print(f'Criando Nuvem de Palavras sem tratamento para ter ideia do corpus.')
# Variável recebe conteúdo do dataframe palavras concatenando cada conteúdo do texto separando por espaço
wordcloud_palavras_titulo = " ".join(s for s in palavras_titulo)
#wordcloud_palavras

# %%
print(f'Quantidade de palavras no corpus: {len(wordcloud_palavras_titulo)} e seu tipo atual é {type(wordcloud_palavras_titulo)}')

# %%
print(f'Criação da nuvem de palavras sem tratamento nos textos')
wordcloud_titulo = WordCloud(stopwords=stopwords,
                      background_color='black', width=1600,                            
                      height=800).generate(wordcloud_palavras_titulo)

# %%
#Gráfico Nuvem de Palavras
# Gerando o grafico 
# Variáveis do gráfico 
path_image = '../image/'

titulo = 'Nuvem de Palavras'
#eixo_x = ''
#eixo_y = ''
image = path_image+'wordcloud_titulo'
extensao_arquivo = '.pdf'

#Gráfico
fig, ax = plt.subplots(figsize=(16,8))            
ax.imshow(wordcloud_titulo, interpolation='bilinear')
ax.set_axis_off()         

#legendas
#ax.legend(title='Legenda', loc=4, fontsize=9)
ax.set_title(titulo, fontsize=18)
#ax.set_xlabel(eixo_x, fontsize=9)
#ax.set_ylabel(eixo_y, fontsize=9)

#salvar imagens
plt.savefig(image+extensao_arquivo) #, format='pdf', dpi=300, transparent=True)
plt.tight_layout() 
plt.show()

# %% [markdown]
# #### Nuvem de Palavras dos Resumos

# %%
print('Carregar novo dataframe de palavras apenas com dados da coluna texto, ou seja, uma série.')
palavras_resumo = df_scopus['resumo'].str.lower()
palavras_resumo

# %%
print(f'Criando Nuvem de Palavras sem tratamento para ter ideia do corpus.')
# Variável recebe conteúdo do dataframe palavras concatenando cada conteúdo do texto separando por espaço
wordcloud_palavras_resumo = " ".join(s for s in palavras_resumo)
#wordcloud_palavras

# %%
print(f'Quantidade de palavras no corpus: {len(wordcloud_palavras_resumo)} e seu tipo atual é{type(wordcloud_palavras_resumo)}')

# %%
print(f'Criação da nuvem de palavras sem tratamento nos textos')
wordcloud_resumo = WordCloud(stopwords=stopwords,
                      background_color='black', width=1600,                            
                      height=800).generate(wordcloud_palavras_resumo)

# %%
#Gráfico Nuvem de Palavras
path_image = '../image/'

titulo = 'Nuvem de Palavras'
#eixo_x = ''
#eixo_y = ''
image = path_image+'wordcloud_resumo'
extensao_arquivo = '.pdf'

#Gráfico
fig, ax = plt.subplots(figsize=(16,8))            
ax.imshow(wordcloud_resumo, interpolation='bilinear')
ax.set_axis_off()         

#legendas
#ax.legend(title='Legenda', loc=4, fontsize=9)
ax.set_title(titulo, fontsize=18)
#ax.set_xlabel(eixo_x, fontsize=9)
#ax.set_ylabel(eixo_y, fontsize=9)

#salvar imagens
plt.savefig(image+extensao_arquivo) #, format='pdf', dpi=300, transparent=True)
plt.tight_layout() 
plt.show()

# %% [markdown]
# ## Exportação do resultado para Excel

# %%
#df_scopus.columns
# Out:
# Index(['autores_scopus', 'id_autores', 'titulo_documento', 'ano',
#        'titulo_fonte', 'volume', 'publicado', 'numero_documento',
#        'inicio_pagina', 'fim_pagina', 'quantidade_paginas',
#        'quantidade_citacoes', 'doi_scopus', 'link_scopus', 'afiliacoes',
#        'autores_com_filiacoes', 'resumo', 'palavras_chaves_autor',
#        'palavras_chave_index', 'numeros_sequencia_molecular', 'chemicals_cas',
#        'nomes_comerciais', 'fabricantes', 'detalhes_financiamento',
#        'texto_financiamento_1', 'texto_financiamento_2',
#        'texto_financiamento_3', 'texto_financiamento_4',
#        'texto_financiamento_5', 'texto_financiamento_6',
#        'texto_financiamento_7', 'texto_financiamento_8',
#        'texto_financiamento_9', 'texto_financiamento_10', 'referencias',
#        'endereco_correspondencia', 'editores', 'patrocinadores', 'editor',
#        'nome_conferencia', 'data_conferencia', 'local_conferencia',
#        'codigo_conferencia', 'issn_scopus', 'isbn', 'coden', 'id_pubmed',
#        'idioma_original', 'titulo_abreviado_fonte', 'tipo_documento',
#        'etapa_publicacao', 'acesso_livre', 'fonte', 'eid', 'doi',
#        'titulo_documento_scopus', 'inicio_pagina_', 'fim_pagina_',
#        'status_pagina', 'quantidade_paginas_'],
#       dtype='object')

# %%
## Gerar planilha com colunas especificas
#resultado_scopus = os.path.join('../data','scopus-08-06-2022.csv')
#resultado_scopus = os.path.join('../data','resultado_scopus-26-06-2022.xlsx')
resultado_scopus = os.path.join('../data','resultado_scopus_'+dataFormatada+'.xlsx')
sheetname="base_scopus"

df_xlsx_scopus = pd.DataFrame(df_scopus, columns = [
       'issn_scopus','titulo_documento', 'ano','quantidade_citacoes', 'tipo_documento', 'nome_conferencia',
       'editores', 'patrocinadores', 'editor',
       'autores', 'id_autores', 'titulo_fonte',
       'volume', 'publicado', 'numero_documento',
       'inicio_pagina', 'fim_pagina','quantidade_paginas','inicio_pagina_','fim_pagina_','quantidade_paginas_',
       'doi', 'link_scopus',
       'afiliacoes', 'autores_com_filiacoes', 'resumo',
       'palavras_chaves_autor', 'palavras_chave_index',
       'numeros_sequencia_molecular', 'chemicals_cas', 'nomes_comerciais',
       'fabricantes',
       'detalhes_financiamento', 'texto_financiamento_1','texto_financiamento_2', 'texto_financiamento_3',
       'texto_financiamento_4','texto_financiamento_5', 'texto_financiamento_6', 'texto_financiamento_7',
       'texto_financiamento_8','texto_financiamento_9', 'texto_financiamento_10',
       'referencias', 'endereco_correspondencia', 
       'data_conferencia', 'local_conferencia',
       'codigo_conferencia', 'isbn', 'coden', 'id_pubmed',
       'idioma_original', 'titulo_abreviado_fonte', 
       'etapa_publicacao', 'acesso_livre', 'fonte', 'eid'
    ,])
df_xlsx_scopus = df_xlsx_scopus.to_excel(resultado_scopus, sheet_name=sheetname, index=False, encoding='utf-8', header=True)

# %% [markdown]
# # Carga de arquivo -  PubMed

# %%
print('Carga e Visualização do dataframe')
arquivo_base_pubmed = os.path.join('../data','pubmed-csv-naturallan-set-2022.csv')
raw_data_pubmed = pd.read_csv(arquivo_base_pubmed, sep=",", delimiter=None, encoding='utf-8')
raw_data_pubmed.head(3)
# Out:
# Carga e Visualização do dataframe
#        PMID  \
# 0  34653809
# 1  34406803
# 2  28643174
#
#                                                                                                                                      Title  \
# 0  Automation of penicillin adverse drug reaction categorisation and risk stratification with machine learning natural language processing
# 1                                                                       Customizable Natural Language Processing Biomarker Extraction Tool
# 2                                                         Natural Language Processing for EHR-Based Pharmacovigilance: A Structured Review
#
#                                                                                        Authors  \
# 0                                        Inglis JM, Bacchi S, Troelnikov A, Smith W, Shakib S.
# 1  Holmes B, Chitale D, Loving J, Tran M, Subramanian V, Berry A, Rioth M, Warrier R, Brown T.
# 2    Luo Y, Thompson WK, Herr TM, Zeng Z, Berendsen MA, Jonnalagadda SR, Carson MB, Starren J.
#
#                                                                                        Citation  \
# 0  Int J Med Inform. 2021 Dec;156:104611. doi: 10.1016/j.ijmedinf.2021.104611. Epub 2021 Oct 5.
# 1                        JCO Clin Cancer Inform. 2021 Aug;5:833-841. doi: 10.1200/CCI.21.00017.
# 2                          Drug Saf. 2017 Nov;40(11):1075-1089. doi: 10.1007/s40264-017-0558-6.
#
#   First Author            Journal/Book  Publication Year Create Date PMCID  \
# 0    Inglis JM        Int J Med Inform              2021  2021/10/15   NaN
# 1     Holmes B  JCO Clin Cancer Inform              2021  2021/08/18   NaN
# 2        Luo Y                Drug Saf              2017  2017/06/24   NaN
#
#   NIHMS ID                             DOI
# 0      NaN  10.1016/j.ijmedinf.2021.104611
# 1      NaN            10.1200/CCI.21.00017
# 2      NaN       10.1007/s40264-017-0558-6

# %% [markdown]
# ## Análise do dataframe - PUBMED

# %% [markdown]
# ### Colunas, dados nulos e tipos de dados

# %%
print('Verificando tipos e se tem dados nulos')
raw_data_pubmed.info()
# Out:
# Verificando tipos e se tem dados nulos
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   PMID              188 non-null    int64
#  1   Title             188 non-null    object
#  2   Authors           188 non-null    object
#  3   Citation          188 non-null    object
#  4   First Author      188 non-null    object
#  5   Journal/Book      188 non-null    object
#  6   Publication Year  188 non-null    int64
#  7   Create Date       188 non-null    object
#  8   PMCID             134 non-null    object
#  9   NIHMS ID          20 non-null     object
#  10  DOI               158 non-null    object
# dtypes: int64(2), object(9)
# memory usage: 16.3+ KB

# %% [markdown]
# ### Quantidade de conteúdo único para cada coluna

# %%
raw_data_pubmed.nunique()
# Out:
# PMID                188
# Title               187
# Authors             185
# Citation            188
# First Author        165
# Journal/Book         63
# Publication Year     20
# Create Date         173
# PMCID               134
# NIHMS ID             20
# DOI                 158
# dtype: int64

# %% [markdown]
# ### Quantidade de conteúdo nulo para cada coluna

# %%
# verificar campos nulos
raw_data_pubmed.isnull().sum()
# Out:
# PMID                  0
# Title                 0
# Authors               0
# Citation              0
# First Author          0
# Journal/Book          0
# Publication Year      0
# Create Date           0
# PMCID                54
# NIHMS ID            168
# DOI                  30
# dtype: int64

# %% [markdown]
# ### Resumo Estatístico de Campos Numéricos

# %%
raw_data_pubmed.describe()
# Out:
#                PMID  Publication Year
# count  1.880000e+02        188.000000
# mean   2.925529e+07       2017.196809
# std    4.823380e+06          4.122274
# min    1.182515e+07       2001.000000
# 25%    2.653983e+07       2015.000000
# 50%    3.000997e+07       2018.000000
# 75%    3.291973e+07       2020.000000
# max    3.561223e+07       2022.000000

# %% [markdown]
# ## Manutenção de dados

# %%
## Verificar se os dataframes nao s"ao espelhos
df_pubmed = raw_data_pubmed.copy()
print(id(df_pubmed), id(raw_data_pubmed))
# Out:
# 1967125074208 1967125949136

# %% [markdown]
# ### Ajustar nome das Colunas

# %%
print('Verificar colunas')
df_pubmed.columns
# Out:
# Verificar colunas
# Index(['PMID', 'Title', 'Authors', 'Citation', 'First Author', 'Journal/Book',
#        'Publication Year', 'Create Date', 'PMCID', 'NIHMS ID', 'DOI'],
#       dtype='object')

# %%
columns_pubmed = {
    'PMID':'id_pubmed',
    'Title':'titulo_documento',
    'Authors':'autores_pubmed',
    'Citation':'citacao_pubmed',
    'First Author':'primeiro_autor_pubmed',
    'Journal/Book':'jornal_book_pubmed',
    'Publication Year':'ano_publicacao_pubmed',
    'Create Date':'data_criacao_pubmed', 
    'PMCID':'id_pmc_pubmed', 
    'NIHMS ID':'id_nihms_pubmed', 
    'DOI':'doi_pubmed',
}

# %%
df_pubmed = df_pubmed.rename(columns=columns_pubmed)
df_pubmed.head(2)
# Out:
#    id_pubmed  \
# 0   34653809
# 1   34406803
#
#                                                                                                                           titulo_documento  \
# 0  Automation of penicillin adverse drug reaction categorisation and risk stratification with machine learning natural language processing
# 1                                                                       Customizable Natural Language Processing Biomarker Extraction Tool
#
#                                                                                 autores_pubmed  \
# 0                                        Inglis JM, Bacchi S, Troelnikov A, Smith W, Shakib S.
# 1  Holmes B, Chitale D, Loving J, Tran M, Subramanian V, Berry A, Rioth M, Warrier R, Brown T.
#
#                                                                                  citacao_pubmed  \
# 0  Int J Med Inform. 2021 Dec;156:104611. doi: 10.1016/j.ijmedinf.2021.104611. Epub 2021 Oct 5.
# 1                        JCO Clin Cancer Inform. 2021 Aug;5:833-841. doi: 10.1200/CCI.21.00017.
#
#   primeiro_autor_pubmed      jornal_book_pubmed  ano_publicacao_pubmed  \
# 0             Inglis JM        Int J Med Inform                   2021
# 1              Holmes B  JCO Clin Cancer Inform                   2021
#
#   data_criacao_pubmed id_pmc_pubmed id_nihms_pubmed  \
# 0          2021/10/15           NaN             NaN
# 1          2021/08/18           NaN             NaN
#
#                        doi_pubmed
# 0  10.1016/j.ijmedinf.2021.104611
# 1            10.1200/CCI.21.00017

# %% [markdown]
# ### Criação de colunas

# %%
## criar uma coluna fonte com valor = pubmed
df_pubmed['fonte']='PubMed' # variavel para receber a base indexada do documento

# %%
df_pubmed["doi"] = df_pubmed["doi_pubmed"]

# %%
df_pubmed["titulo_documento_pubmed"] = df_pubmed["titulo_documento"]

# %% [markdown]
# ### Ajuste de textos de algumas colunas para minúsculo (lower)

# %%
df_pubmed["titulo_documento"] = df_pubmed["titulo_documento"].str.lower()
df_pubmed["doi"] = df_pubmed["doi"].str.lower()

# %% [markdown]
# ### Remover caracteres especiais

# %%
df_pubmed["titulo_documento"] = df_pubmed["titulo_documento"].apply(lambda x: re.sub('\?|\*|;|,|\.|-|–|:|“|”|"|—|•', ' ', x))

# %%
df_pubmed.loc[:,'titulo_documento'] = df_pubmed['titulo_documento'].apply(limpar_campo)

# %%
df_pubmed['titulo_documento'] = df_pubmed['titulo_documento'].str.replace('  ', ' ')

# %% [markdown]
# ### Remoção de espaços de textos de algumas colunas (strip)

# %%
df_pubmed["titulo_documento"] = df_pubmed["titulo_documento"].str.strip()

# %% [markdown]
# ### Ajustar tipagem de dados

# %%
print('Ajustar tipagem dos dados')
df_pubmed['jornal_book_pubmed'] = df_pubmed['jornal_book_pubmed'].astype('category')
# Out:
# Ajustar tipagem dos dados

# %% [markdown]
# ## Exclusão de documentos duplicados

# %%
# Ordenando para excluir primeiro as duplicidades
df_pubmed = df_pubmed.sort_values(['ano_publicacao_pubmed','doi_pubmed','titulo_documento'])
df_pubmed[['doi_pubmed','titulo_documento']]
# Out:
#                         doi_pubmed  \
# 139                            NaN
# 165      10.1016/j.jbi.2003.09.017
# 183                            NaN
# 160                            NaN
# 180                            NaN
# ..                             ...
# 163             10.3233/SHTI220615
# 88   10.3390/pharmaceutics14020266
# 178       10.3390/vaccines10010103
# 186                            NaN
# 169                            NaN
#
#                                                                                                         titulo_documento
# 139                                   effective mapping of biomedical text to the umls metathesaurus the metamap program
# 165                                  towards linking patients and clinical information detecting umls concepts in e mail
# 183                                  linguistic analysis terms and phrases used by patients in e mail messages to nurses
# 160                          comparing natural language processing tools to extract medical problems from narrative text
# 180            evaluation of medical problem extraction from electronic clinical documents using metamap transfer (mmtx)
# ..                                                                                                                   ...
# 163                               named entity recognition in pubmed abstracts for pharmacovigilance using deep learning
# 88                                                      using machine learning for pharmacovigilance a systematic review
# 178                 using a machine learning approach to monitor covid 19 vaccine adverse events (vae) from twitter data
# 186        clinical note section detection using a hidden markov model of unified medical language system semantic types
# 169  reducing physicians' cognitive load during chart review a problem oriented summary of the patient electronic record
#
# [188 rows x 2 columns]

# %%
# 1 documentos duplicados
df_pubmed.titulo_documento.value_counts()
# Out:
# semantic processing to identify adverse drug event information from black box warnings                                                                      2
# effective mapping of biomedical text to the umls metathesaurus the metamap program                                                                          1
# ensemble method based extraction of medication and related information from clinical texts                                                                  1
# patient reported outcomes in online communications on statins memory and cognition qualitative analysis using online communities                            1
# fine tuning bidirectional encoder representations from transformers (bert) based models on large scale electronic health record notes an empirical study    1
#                                                                                                                                                            ..
# deep learning for pharmacovigilance recurrent neural network architectures for labeling adverse drug reactions in twitter posts                             1
# knowledge based biomedical word sense disambiguation with neural concept embeddings                                                                         1
# deep gramulator improving precision in the classification of personal health experience tweets with deep learning                                           1
# combination of deep recurrent neural networks and conditional random fields for extracting adverse drug reactions from user reviews                         1
# reducing physicians' cognitive load during chart review a problem oriented summary of the patient electronic record                                         1
# Name: titulo_documento, Length: 187, dtype: int64

# %%
''' estranho, tem dois artigos, o de 2014 parece ser mais completo, ficando com ele
links:
2013 - https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3900176/
2014 - https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4419903/

'''

df_pubmed.query('titulo_documento == "semantic processing to identify adverse drug event information from black box warnings" ')[['id_pubmed', 'titulo_documento','ano_publicacao_pubmed', 'doi_pubmed','doi']]
# Out:
#      id_pubmed  \
# 161   24551335
# 34    25954348
#
#                                                                            titulo_documento  \
# 161  semantic processing to identify adverse drug event information from black box warnings
# 34   semantic processing to identify adverse drug event information from black box warnings
#
#      ano_publicacao_pubmed doi_pubmed  doi
# 161                   2013        NaN  NaN
# 34                    2014        NaN  NaN

# %%
df_pubmed = df_pubmed.drop_duplicates(['titulo_documento','doi_pubmed'], keep='last') ## de 188 para [187 rows x 14 columns]
print(df_pubmed)
# Out:
#      id_pubmed  \
# 139   11825149
# 165   14643729
# 183   15360865
# 160   16779095
# 180   16160360
# ..         ...
# 163   35612234
# 88    35213998
# 178   35062764
# 186   35308919
# 169   35308927
#
#                                                                                                         titulo_documento  \
# 139                                   effective mapping of biomedical text to the umls metathesaurus the metamap program
# 165                                  towards linking patients and clinical information detecting umls concepts in e mail
# 183                                  linguistic analysis terms and phrases used by patients in e mail messages to nurses
# 160                          comparing natural language processing tools to extract medical problems from narrative text
# 180            evaluation of medical problem extraction from electronic clinical documents using metamap transfer (mmtx)
# ..                                                                                                                   ...
# 163                               named entity recognition in pubmed abstracts for pharmacovigilance using deep learning
# 88                                                      using machine learning for pharmacovigilance a systematic review
# 178                 using a machine learning approach to monitor covid 19 vaccine adverse events (vae) from twitter data
# 186        clinical note section detection using a hidden markov model of unified medical language system semantic types
# 169  reducing physicians' cognitive load during chart review a problem oriented summary of the patient electronic record
#
#                                                                                    autores_pubmed  \
# 139                                                                                   Aronson AR.
# 165                                                                       Brennan PF, Aronson AR.
# 183                                                         Hsieh Y, Hardardottir GA, Brennan PF.
# 160                                                                          Meystre SM, Haug PJ.
# 180                                                                           Meystre S, Haug PJ.
# ..                                                                                            ...
# 163                                                                        Nghiem TT, Bousquet C.
# 88                                                                 Pilipiec P, Liwicki M, Bota A.
# 178                                                                        Lian AT, Du J, Tang L.
# 186                                                      Eisman AS, Brown KA, Chen ES, Sarkar IN.
# 169  Liang JJ, Tsou CH, Dandala B, Poddar A, Joopudi V, Mahajan D, Prager J, Raghavan P, Payne M.
#
#                                                                     citacao_pubmed  \
# 139                                                    Proc AMIA Symp. 2001:17-21.
# 165  J Biomed Inform. 2003 Aug-Oct;36(4-5):334-41. doi: 10.1016/j.jbi.2003.09.017.
# 183                              Stud Health Technol Inform. 2004;107(Pt 1):511-5.
# 160                                          AMIA Annu Symp Proc. 2005;2005:525-9.
# 180                                    Stud Health Technol Inform. 2005;116:823-8.
# ..                                                                             ...
# 163  Stud Health Technol Inform. 2022 May 25;294:878-879. doi: 10.3233/SHTI220615.
# 88       Pharmaceutics. 2022 Jan 23;14(2):266. doi: 10.3390/pharmaceutics14020266.
# 178        Vaccines (Basel). 2022 Jan 11;10(1):103. doi: 10.3390/vaccines10010103.
# 186               AMIA Annu Symp Proc. 2022 Feb 21;2021:418-427. eCollection 2021.
# 169               AMIA Annu Symp Proc. 2022 Feb 21;2021:763-772. eCollection 2021.
#
#     primeiro_autor_pubmed          jornal_book_pubmed  ano_publicacao_pubmed  \
# 139            Aronson AR              Proc AMIA Symp                   2001
# 165            Brennan PF             J Biomed Inform                   2003
# 183               Hsieh Y  Stud Health Technol Inform                   2004
# 160            Meystre SM         AMIA Annu Symp Proc                   2005
# 180             Meystre S  Stud Health Technol Inform                   2005
# ..                    ...                         ...                    ...
# 163             Nghiem TT  Stud Health Technol Inform                   2022
# 88             Pilipiec P               Pharmaceutics                   2022
# 178               Lian AT            Vaccines (Basel)                   2022
# 186             Eisman AS         AMIA Annu Symp Proc                   2022
# 169              Liang JJ         AMIA Annu Symp Proc                   2022
#
#     data_criacao_pubmed id_pmc_pubmed id_nihms_pubmed  \
# 139          2002/02/05    PMC2243666             NaN
# 165          2003/12/04           NaN             NaN
# 183          2004/09/14           NaN             NaN
# 160          2006/06/17    PMC1560561             NaN
# 180          2005/09/15           NaN             NaN
# ..                  ...           ...             ...
# 163          2022/05/25           NaN             NaN
# 88           2022/02/26    PMC8924891             NaN
# 178          2022/01/22    PMC8781534             NaN
# 186          2022/03/21    PMC8861726             NaN
# 169          2022/03/21    PMC8861663             NaN
#
#                         doi_pubmed   fonte                            doi  \
# 139                            NaN  PubMed                            NaN
# 165      10.1016/j.jbi.2003.09.017  PubMed      10.1016/j.jbi.2003.09.017
# 183                            NaN  PubMed                            NaN
# 160                            NaN  PubMed                            NaN
# 180                            NaN  PubMed                            NaN
# ..                             ...     ...                            ...
# 163             10.3233/SHTI220615  PubMed             10.3233/shti220615
# 88   10.3390/pharmaceutics14020266  PubMed  10.3390/pharmaceutics14020266
# 178       10.3390/vaccines10010103  PubMed       10.3390/vaccines10010103
# 186                            NaN  PubMed                            NaN
# 169                            NaN  PubMed                            NaN
#
#                                                                                                   titulo_documento_pubmed
# 139                                   Effective mapping of biomedical text to the UMLS Metathesaurus: the MetaMap program
# 165                                  Towards linking patients and clinical information: detecting UMLS concepts in e-mail
# 183                                  Linguistic analysis: terms and phrases used by patients in e-mail messages to nurses
# 160                           Comparing natural language processing tools to extract medical problems from narrative text
# 180             Evaluation of Medical Problem Extraction from Electronic Clinical Documents Using MetaMap Transfer (MMTx)
# ..                                                                                                                    ...
# 163                                Named Entity Recognition in Pubmed Abstracts for Pharmacovigilance Using Deep Learning
# 88                                                      Using Machine Learning for Pharmacovigilance: A Systematic Review
# 178                  Using a Machine Learning Approach to Monitor COVID-19 Vaccine Adverse Events (VAE) from Twitter Data
# 186         Clinical Note Section Detection Using a Hidden Markov Model of Unified Medical Language System Semantic Types
# 169  Reducing Physicians' Cognitive Load During Chart Review: A Problem-Oriented Summary of the Patient Electronic Record
#
# [187 rows x 14 columns]

# %%
df_pubmed.query('titulo_documento == "semantic processing to identify adverse drug event information from black box warnings" ')[['id_pubmed', 'titulo_documento','ano_publicacao_pubmed', 'doi']]
# Out:
#     id_pubmed  \
# 34   25954348
#
#                                                                           titulo_documento  \
# 34  semantic processing to identify adverse drug event information from black box warnings
#
#     ano_publicacao_pubmed  doi
# 34                   2014  NaN

# %% [markdown]
#  ## Reanálise do dataframe

# %%
print('Verificando tipos e se tem dados nulos')
df_pubmed.info()
# Out:
# Verificando tipos e se tem dados nulos
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 187 entries, 139 to 169
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id_pubmed                187 non-null    int64
#  1   titulo_documento         187 non-null    object
#  2   autores_pubmed           187 non-null    object
#  3   citacao_pubmed           187 non-null    object
#  4   primeiro_autor_pubmed    187 non-null    object
#  5   jornal_book_pubmed       187 non-null    category
#  6   ano_publicacao_pubmed    187 non-null    int64
#  7   data_criacao_pubmed      187 non-null    object
#  8   id_pmc_pubmed            133 non-null    object
#  9   id_nihms_pubmed          20 non-null     object
#  10  doi_pubmed               158 non-null    object
#  11  fonte                    187 non-null    object
#  12  doi                      158 non-null    object
#  13  titulo_documento_pubmed  187 non-null    object
# dtypes: category(1), int64(2), object(11)
# memory usage: 23.2+ KB

# %%
df_pubmed.nunique()
# Out:
# id_pubmed                  187
# titulo_documento           187
# autores_pubmed             185
# citacao_pubmed             187
# primeiro_autor_pubmed      165
# jornal_book_pubmed          63
# ano_publicacao_pubmed       20
# data_criacao_pubmed        173
# id_pmc_pubmed              133
# id_nihms_pubmed             20
# doi_pubmed                 158
# fonte                        1
# doi                        158
# titulo_documento_pubmed    187
# dtype: int64

# %%
df_pubmed.isnull().sum()
# Out:
# id_pubmed                    0
# titulo_documento             0
# autores_pubmed               0
# citacao_pubmed               0
# primeiro_autor_pubmed        0
# jornal_book_pubmed           0
# ano_publicacao_pubmed        0
# data_criacao_pubmed          0
# id_pmc_pubmed               54
# id_nihms_pubmed            167
# doi_pubmed                  29
# fonte                        0
# doi                         29
# titulo_documento_pubmed      0
# dtype: int64

# %%
print('Resumo Estatístico de Campos Numéricos')
df_pubmed['ano_publicacao_pubmed'].describe()
# Out:
# Resumo Estatístico de Campos Numéricos
# count     187.000000
# mean     2017.219251
# std         4.121808
# min      2001.000000
# 25%      2015.000000
# 50%      2018.000000
# 75%      2020.000000
# max      2022.000000
# Name: ano_publicacao_pubmed, dtype: float64

# %% [markdown]
# ## Visualização

# %% [markdown]
# ### Analisando documentos por Ano

# %%
ano_pubmed = df_pubmed.groupby("ano_publicacao_pubmed")
ano_pubmed.describe()

# %%
## Ordenar por ano
plt.figure(figsize=(15,10))
ano_pubmed.size().sort_values(ascending=False).plot.bar()
plt.xticks(rotation=50)
plt.xlabel("Anos")
plt.ylabel("Número de Documentos")
plt.show()

# %% [markdown]
# ### Analisando documentos por Jornal

# %%
jornal_book_pubmed = df_pubmed.groupby("jornal_book_pubmed")
jornal_book_pubmed.describe()

# %%
## Pegar os 10 +
plt.figure(figsize=(15,10))
jornal_book_pubmed.size().sort_values(ascending=False).plot.bar()
plt.xticks(rotation=50)
plt.xlabel("Jornal")
plt.ylabel("Número de Documentos")
plt.show()

# %% [markdown]
# ### Seaborn - colunas x colunas

# %%
print('Visão geral em gráfico')
sns.pairplot(df_pubmed)

# %% [markdown]
# ### Nuvem de Palavras

# %% [markdown]
# #### Nuvem de Palavras dos Títulos

# %%
print('Carregar novo dataframe de palavras apenas com dados da coluna texto, ou seja, uma série.')
palavras_titulo_pubmed = df_pubmed['titulo_documento'].str.lower()
palavras_titulo_pubmed

# %%
wordcloud_palavras_titulo_pubmed = " ".join(s for s in palavras_titulo_pubmed)
print(f'Quantidade de palavras no corpus: {len(wordcloud_palavras_titulo_pubmed)} e seu tipo atual é{type(wordcloud_palavras_titulo_pubmed)}')

# %%
print(f'Criação da nuvem de palavras sem tratamento nos textos')
wordcloud_titulo_pubmed = WordCloud(stopwords=stopwords,
                      background_color='black', width=1600,                            
                      height=800).generate(wordcloud_palavras_titulo_pubmed)

# %%
path_image = '../image/'

titulo = 'Nuvem de Palavras'
#eixo_x = ''
#eixo_y = ''
image = path_image+'wordcloud_titulo_pubmed'
extensao_arquivo = '.pdf'

#Gráfico
fig, ax = plt.subplots(figsize=(16,8))            
ax.imshow(wordcloud_titulo_pubmed, interpolation='bilinear')
ax.set_axis_off()         

#legendas
#ax.legend(title='Legenda', loc=4, fontsize=9)
ax.set_title(titulo, fontsize=18)
#ax.set_xlabel(eixo_x, fontsize=9)
#ax.set_ylabel(eixo_y, fontsize=9)

#salvar imagens
plt.savefig(image+extensao_arquivo) #, format='pdf', dpi=300, transparent=True)
plt.tight_layout() 
plt.show()

# %% [markdown]
# ## Exportação do resultado para Excel

# %%
df_pubmed.columns
# Out:
# Index(['id_pubmed', 'titulo_documento', 'autores_pubmed', 'citacao_pubmed',
#        'primeiro_autor_pubmed', 'jornal_book_pubmed', 'ano_publicacao_pubmed',
#        'data_criacao_pubmed', 'id_pmc_pubmed', 'id_nihms_pubmed', 'doi_pubmed',
#        'fonte', 'doi', 'titulo_documento_pubmed'],
#       dtype='object')

# %%
## Gerar planilha com colunas especificas
#resultado_geral = os.path.join('../data','scopus-31-05-2021.csv')
resultado_pubmed = os.path.join('../data','resultado_pubmed-'+dataFormatada+'.xlsx')
sheetname="base_pubmed"

df_xlsx_pubmed = pd.DataFrame(df_pubmed, columns = [
    'id_pubmed', 'titulo_documento','titulo_documento_pubmed','ano_publicacao_pubmed','fonte','autores_pubmed', 'citacao_pubmed',
    'primeiro_autor_pubmed', 'jornal_book_pubmed','data_criacao_pubmed',
    'id_pmc_pubmed', 'id_nihms_pubmed', 'doi','doi_pubmed'
    ,])
df_xlsx_pubmed = df_xlsx_pubmed.to_excel(resultado_pubmed,sheet_name=sheetname,index=False, encoding='utf-8', header=True)

# %% [markdown]
# # Concatenação de dataframes

# %%
#https://www.acervolima.com.br/2020/08/concat-e-append-do-pandas-como-usar.html
qtde_scopus = df_scopus.titulo_documento.count()
qtde_pubmed = df_pubmed.titulo_documento.count()

# 3 colunas em comum: titulo_documento, id_pubmed, fonte
shape_scopus = df_scopus.shape
shape_pubmed = df_pubmed.shape

print(f'A quantidade de documentos na base scopus é: {qtde_scopus} e a quantidade de colunas é {shape_scopus}')
print(f'A quantidade de documentos na base pubmed é: {qtde_pubmed} e a quantidade de colunas é {shape_pubmed}')
print(f'O total de documentos concatedos tem que ser {qtde_pubmed+qtde_scopus}')
# Out:
# A quantidade de documentos na base scopus é: 523 e a quantidade de colunas é (523, 60)
# A quantidade de documentos na base pubmed é: 187 e a quantidade de colunas é (187, 14)
# O total de documentos concatedos tem que ser 710

# %%
frames = [df_scopus, df_pubmed]
df_bases = pd.concat(frames)
df_bases

# %%
# Out:
#                                                                   autores_scopus  \
# 95                  Corso D.M., Pucino F., DeLeo J.M., Calis K.A., Gallelli J.F.
# 129                                           Yokotsuka M., Aoyama M., Kubota K.
# 0                                                                   Aronson A.R.
# 3    Bates D.W., Evans R.S., Murff H., Stetson P.D., Pizzifferri L., Hripcsak G.
# 63                                                    Brennan P.F., Aronson A.R.
# ..                                                                           ...
# 163                                                                          NaN
# 88                                                                           NaN
# 178                                                                          NaN
# 186                                                                          NaN
# 169                                                                          NaN
#
#                                                               id_autores  \
# 95             6602576929;6701705695;35579441300;57221571096;7003762821;
# 129                                   6505861090;7202591218;24356074400;
# 0                                                           17933416200;
# 3    57113031900;7405652324;6701719661;7005833624;6508207735;7004471151;
# 63                                              35473309900;17933416200;
# ..                                                                   ...
# 163                                                                  NaN
# 88                                                                   NaN
# 178                                                                  NaN
# 186                                                                  NaN
# 169                                                                  NaN
#
#                                                                                                                      titulo_documento  \
# 95                                                      development of a questionnaire for detecting potential adverse drug reactions
# 129  the use of a medical dictionary for regulatory activities terminology (meddra) in prescription event monitoring in japan (j pem)
# 0                                                  effective mapping of biomedical text to the umls metathesaurus the metamap program
# 3                                                                               detecting adverse events using information technology
# 63                                                towards linking patients and clinical information detecting umls concepts in e mail
# ..                                                                                                                                ...
# 163                                            named entity recognition in pubmed abstracts for pharmacovigilance using deep learning
# 88                                                                   using machine learning for pharmacovigilance a systematic review
# 178                              using a machine learning approach to monitor covid 19 vaccine adverse events (vae) from twitter data
# 186                     clinical note section detection using a hidden markov model of unified medical language system semantic types
# 169               reducing physicians' cognitive load during chart review a problem oriented summary of the patient electronic record
#
#         ano                                             titulo_fonte volume  \
# 95   1992.0                                Annals of Pharmacotherapy     26
# 129  2000.0             International Journal of Medical Informatics     57
# 0    2001.0  Proceedings / AMIA ... Annual Symposium. AMIA Symposium    NaN
# 3    2003.0  Journal of the American Medical Informatics Association     10
# 63   2003.0                        Journal of Biomedical Informatics     36
# ..      ...                                                      ...    ...
# 163     NaN                                                      NaN    NaN
# 88      NaN                                                      NaN    NaN
# 178     NaN                                                      NaN    NaN
# 186     NaN                                                      NaN    NaN
# 169     NaN                                                      NaN    NaN
#
#     publicado numero_documento inicio_pagina fim_pagina  ...  \
# 95        7-8              NaN           890        896  ...
# 129       2-3              NaN           139        153  ...
# 0         NaN              NaN            17         21  ...
# 3           2              NaN           115        128  ...
# 63        4-5              NaN           334        341  ...
# ..        ...              ...           ...        ...  ...
# 163       NaN              NaN           NaN        NaN  ...
# 88        NaN              NaN           NaN        NaN  ...
# 178       NaN              NaN           NaN        NaN  ...
# 186       NaN              NaN           NaN        NaN  ...
# 169       NaN              NaN           NaN        NaN  ...
#
#                                                                                    autores_pubmed  \
# 95                                                                                            NaN
# 129                                                                                           NaN
# 0                                                                                             NaN
# 3                                                                                             NaN
# 63                                                                                            NaN
# ..                                                                                            ...
# 163                                                                        Nghiem TT, Bousquet C.
# 88                                                                 Pilipiec P, Liwicki M, Bota A.
# 178                                                                        Lian AT, Du J, Tang L.
# 186                                                      Eisman AS, Brown KA, Chen ES, Sarkar IN.
# 169  Liang JJ, Tsou CH, Dandala B, Poddar A, Joopudi V, Mahajan D, Prager J, Raghavan P, Payne M.
#
#                                                                     citacao_pubmed  \
# 95                                                                             NaN
# 129                                                                            NaN
# 0                                                                              NaN
# 3                                                                              NaN
# 63                                                                             NaN
# ..                                                                             ...
# 163  Stud Health Technol Inform. 2022 May 25;294:878-879. doi: 10.3233/SHTI220615.
# 88       Pharmaceutics. 2022 Jan 23;14(2):266. doi: 10.3390/pharmaceutics14020266.
# 178        Vaccines (Basel). 2022 Jan 11;10(1):103. doi: 10.3390/vaccines10010103.
# 186               AMIA Annu Symp Proc. 2022 Feb 21;2021:418-427. eCollection 2021.
# 169               AMIA Annu Symp Proc. 2022 Feb 21;2021:763-772. eCollection 2021.
#
#     primeiro_autor_pubmed          jornal_book_pubmed ano_publicacao_pubmed  \
# 95                    NaN                         NaN                   NaN
# 129                   NaN                         NaN                   NaN
# 0                     NaN                         NaN                   NaN
# 3                     NaN                         NaN                   NaN
# 63                    NaN                         NaN                   NaN
# ..                    ...                         ...                   ...
# 163             Nghiem TT  Stud Health Technol Inform                2022.0
# 88             Pilipiec P               Pharmaceutics                2022.0
# 178               Lian AT            Vaccines (Basel)                2022.0
# 186             Eisman AS         AMIA Annu Symp Proc                2022.0
# 169              Liang JJ         AMIA Annu Symp Proc                2022.0
#
#     data_criacao_pubmed id_pmc_pubmed id_nihms_pubmed  \
# 95                  NaN           NaN             NaN
# 129                 NaN           NaN             NaN
# 0                   NaN           NaN             NaN
# 3                   NaN           NaN             NaN
# 63                  NaN           NaN             NaN
# ..                  ...           ...             ...
# 163          2022/05/25           NaN             NaN
# 88           2022/02/26    PMC8924891             NaN
# 178          2022/01/22    PMC8781534             NaN
# 186          2022/03/21    PMC8861726             NaN
# 169          2022/03/21    PMC8861663             NaN
#
#                         doi_pubmed  \
# 95                             NaN
# 129                            NaN
# 0                              NaN
# 3                              NaN
# 63                             NaN
# ..                             ...
# 163             10.3233/SHTI220615
# 88   10.3390/pharmaceutics14020266
# 178       10.3390/vaccines10010103
# 186                            NaN
# 169                            NaN
#
#                                                                                                   titulo_documento_pubmed
# 95                                                                                                                    NaN
# 129                                                                                                                   NaN
# 0                                                                                                                     NaN
# 3                                                                                                                     NaN
# 63                                                                                                                    NaN
# ..                                                                                                                    ...
# 163                                Named Entity Recognition in Pubmed Abstracts for Pharmacovigilance Using Deep Learning
# 88                                                      Using Machine Learning for Pharmacovigilance: A Systematic Review
# 178                  Using a Machine Learning Approach to Monitor COVID-19 Vaccine Adverse Events (VAE) from Twitter Data
# 186         Clinical Note Section Detection Using a Hidden Markov Model of Unified Medical Language System Semantic Types
# 169  Reducing Physicians' Cognitive Load During Chart Review: A Problem-Oriented Summary of the Patient Electronic Record
#
# [710 rows x 70 columns]

# %% [markdown]
# ## Remover caracteres especiais

# %%
df_bases.query('doi_pubmed == "10.1007/978-3-319-48472-3_43" ')[['titulo_documento','id_pubmed','issn_scopus','doi_scopus','doi_pubmed']]
# Out:
#                                                                                                                    titulo_documento  \
# 100  an ontology enabled natural language processing pipeline for provenance metadata extraction from biomedical text (short paper)
#
#       id_pubmed issn_scopus doi_scopus                    doi_pubmed
# 100  28664200.0         NaN        NaN  10.1007/978-3-319-48472-3_43

# %%
df_bases.query('doi_scopus == "10.1007/978-3-319-48472-3_43" ')[['titulo_documento','id_pubmed','issn_scopus','doi_scopus','doi_pubmed']]
# Out:
#                                                                                                      titulo_documento  \
# 289  an ontology enabled natural language processing pipeline for provenance metadata extraction from biomedical text
#
#      id_pubmed issn_scopus                    doi_scopus doi_pubmed
# 289        NaN    03029743  10.1007/978-3-319-48472-3_43        NaN

# %% [markdown]
# ### Remover caracteres especiais

# %%
#remove números e caracteres especiais
#df_bases["titulo_documento"] = df_bases["titulo_documento"].apply(lambda x: re.sub('\?|\*|;|,|\.|-|–|:|“|”|"|—|•', ' ', x))

df_bases["titulo_documento"] = df_bases["titulo_documento"].apply(lambda x: re.sub('\?|\*|;|,|\.|-|–|:|"|•', ' ', x))

# %%
df_bases.loc[:,'titulo_documento'] = df_bases['titulo_documento'].apply(limpar_campo)

# %%
df_bases['titulo_documento'] = df_bases['titulo_documento'].str.replace('  ', ' ')

# %%
df_bases["titulo_documento"] = df_bases["titulo_documento"].str.strip()

# %%
df_bases.query('doi_pubmed == "10.1007/978-3-319-48472-3_43" ')[['titulo_documento','id_pubmed','issn_scopus','doi_scopus','doi_pubmed']]
# Out:
#                                                                                                                    titulo_documento  \
# 100  an ontology enabled natural language processing pipeline for provenance metadata extraction from biomedical text (short paper)
#
#       id_pubmed issn_scopus doi_scopus                    doi_pubmed
# 100  28664200.0         NaN        NaN  10.1007/978-3-319-48472-3_43

# %% [markdown]
# ## Exclusão de documentos da base final

# %% [markdown]
# ### Exclusão de documentos duplicados

# %%
## ordenando de forma para que fique os documentos da base scopus
df_bases = df_bases.sort_values(['fonte','autores_pubmed'])

# %%
## Length total 724 - sem duplicidades = 553, porém, na exclusão fica 554, ajustado para ficar 553
df_bases.titulo_documento.value_counts()
# Out:
# training augmented intelligent capabilities for pharmacovigilance applying deep learning approaches to individual case safety report processing     2
# comparing the effectiveness of computerized adverse drug event monitoring systems to enhance clinical decision support for hospitalized patients    2
# using natural language processing and network analysis to develop a conceptual framework for medication therapy management research                 2
# on the creation of a clinical gold standard corpus in spanish mining adverse drug reactions                                                         2
# efficient identification of nationally mandated reportable cancer cases using natural language processing and machine learning                      2
#                                                                                                                                                    ..
# analysis of autoimmune diseases and genetic relationships to vaccination against infectious diseases                                                1
# adverse drug event prediction combining shallow analysis and machine learning                                                                       1
# identify disorders in health records using conditional random fields and metamap aehrc at share/clef 2013 ehealth evaluation lab task 1             1
# combining metamap and ctakes in disorder recognition thcib at clef ehealth lab 2013 task 1                                                          1
# on the road to explainable ai in drug drug interactions prediction a systematic review                                                              1
# Name: titulo_documento, Length: 541, dtype: int64

# %%
df_bases.query('titulo_documento == "ai based language models powering drug discovery and development" ')[['eid','fonte','id_pubmed','quantidade_paginas_','titulo_documento']]
# Out:
#                     eid   fonte   id_pubmed  quantidade_paginas_  \
# 5                   NaN  PubMed  34216835.0                  NaN
# 321  2-s2.0-85110540049  Scopus  34216835.0                 15.0
#
#                                                      titulo_documento
# 5    ai based language models powering drug discovery and development
# 321  ai based language models powering drug discovery and development

# %%
df_bases.query('titulo_documento == "adverse drug event discovery using biomedical literature a big data neural network adventure" ')[['eid','fonte','id_pubmed','quantidade_paginas_','titulo_documento']]
# Out:
#                    eid   fonte   id_pubmed  quantidade_paginas_  \
# 37                 NaN  PubMed  29222076.0                  NaN
# 82  2-s2.0-85047825131  Scopus         NaN                  1.0
#
#                                                                                 titulo_documento
# 37  adverse drug event discovery using biomedical literature a big data neural network adventure
# 82  adverse drug event discovery using biomedical literature a big data neural network adventure

# %%
## de 724 para [561 rows x 69 columns] (antigo)
## Novo 710 para 548 rows
df_bases = df_bases.drop_duplicates(['titulo_documento', 'doi'], keep='last') 
print(df_bases)
# Out:
#                                                                                                        autores_scopus  \
# 42                                                                                                                NaN
# 164                                                                                                               NaN
# 85                                                                                                                NaN
# 122                                                                                                               NaN
# 99                                                                                                                NaN
# ..                                                                                                                ...
# 457  Nishioka S., Watanabe T., Asano M., Yamamoto T., Kawakami K., Yada S., Aramaki E., Yajima H., Kizaki H., Hori S.
# 468                                                 Yang J.C., Thygesen J.H., Werbeloff N., Hayes J.F., Osborn D.P.J.
# 467                                                                       Vo T.H., Nguyen N.T.K., Kha Q.H., Le N.Q.K.
# 456                                                                                                      Aronson J.K.
# 455                                              Portelli B., Scaboro S., Tonino R., Chersoni E., Santus E., Serra G.
#
#                                                                                                                   id_autores  \
# 42                                                                                                                       NaN
# 164                                                                                                                      NaN
# 85                                                                                                                       NaN
# 122                                                                                                                      NaN
# 99                                                                                                                       NaN
# ..                                                                                                                       ...
# 457  57665231500;57665866200;57666183300;57666504400;36484772100;57219665421;57203225161;57665866300;57607977600;8058209600;
# 468                                                              57202692614;42162169300;25522505100;36518630100;7101639320;
# 467                                                                         57671574900;57211071169;57224131231;57208281644;
# 456                                                                                                             55683060600;
# 455                                                 57219796263;57274686400;57704816900;57193697675;57189268006;10140344600;
#
#                                                                                                                                                titulo_documento  \
# 42                                                                                 visualising patterns associated with adverse drug reactions in french forums
# 164                                                                           metamap lite in excel biomedical named entity recognition for non technical users
# 85                                                                structuring clinical decision support rules for drug safety using natural language processing
# 122                                                                      v3nlp framework tools to build applications for extracting concepts from clinical text
# 99                                                                                             intelligent telehealth in pharmacovigilance a future perspective
# ..                                                                                                                                                          ...
# 457  identification of hand foot syndrome from cancer patients’ blog posts bert based deep learning approach to detect potential adverse drug reaction symptoms
# 468                                              antipsychotic polypharmacy and adverse drug reactions among adults in a london mental health service 2008 2018
# 467                                                                      on the road to explainable ai in drug drug interactions prediction a systematic review
# 456                                                 artificial intelligence in pharmacovigilance an introduction to terms concepts applications and limitations
# 455                                           monitoring user opinions and side effects on covid 19 vaccines in the twittersphere infodemiology study of tweets
#
#         ano                                        titulo_fonte volume  \
# 42      NaN                                                 NaN    NaN
# 164     NaN                                                 NaN    NaN
# 85      NaN                                                 NaN    NaN
# 122     NaN                                                 NaN    NaN
# 99      NaN                                                 NaN    NaN
# ..      ...                                                 ...    ...
# 457  2022.0                                            PLoS ONE     17
# 468  2022.0                              Psychological Medicine    NaN
# 467  2022.0  Computational and Structural Biotechnology Journal     20
# 456  2022.0                                         Drug Safety     45
# 455  2022.0                Journal of Medical Internet Research     24
#
#     publicado numero_documento inicio_pagina fim_pagina  ...  \
# 42        NaN              NaN           NaN        NaN  ...
# 164       NaN              NaN           NaN        NaN  ...
# 85        NaN              NaN           NaN        NaN  ...
# 122       NaN              NaN           NaN        NaN  ...
# 99        NaN              NaN           NaN        NaN  ...
# ..        ...              ...           ...        ...  ...
# 457     5 May         e0267901           NaN        NaN  ...
# 468       NaN              NaN           NaN        NaN  ...
# 467       NaN              NaN          2112       2123  ...
# 456         5              NaN           407        418  ...
# 455         5           e35115           NaN        NaN  ...
#
#                                                                           autores_pubmed  \
# 42                                             Allam N, Audeh B, Jaulent MC, Bousquet C.
# 164                                              Bhupatiraju RT, Fung KW, Bodenreider O.
# 85                      Despotou G, Korkontzelos I, Matragkas N, Bilici E, Arvanitis TN.
# 122  Divita G, Carter ME, Tran LT, Redd D, Zeng QT, Duvall S, Samore MH, Gundlapalli AV.
# 99                          Edrees H, Song W, Syrowatka A, Simona A, Amato MG, Bates DW.
# ..                                                                                   ...
# 457                                                                                  NaN
# 468                                                                                  NaN
# 467                                                                                  NaN
# 456                                                                                  NaN
# 455                                                                                  NaN
#
#                                                                               citacao_pubmed  \
# 42           Stud Health Technol Inform. 2021 May 27;281:1110-1111. doi: 10.3233/SHTI210368.
# 164                                               Stud Health Technol Inform. 2017;245:1252.
# 85                                               Stud Health Technol Inform. 2018;251:89-92.
# 122  EGEMS (Wash DC). 2016 Aug 11;4(3):1228. doi: 10.13063/2327-9214.1228. eCollection 2016.
# 99      Drug Saf. 2022 May;45(5):449-458. doi: 10.1007/s40264-022-01172-5. Epub 2022 May 17.
# ..                                                                                       ...
# 457                                                                                      NaN
# 468                                                                                      NaN
# 467                                                                                      NaN
# 456                                                                                      NaN
# 455                                                                                      NaN
#
#     primeiro_autor_pubmed          jornal_book_pubmed ano_publicacao_pubmed  \
# 42                Allam N  Stud Health Technol Inform                2021.0
# 164        Bhupatiraju RT  Stud Health Technol Inform                2017.0
# 85             Despotou G  Stud Health Technol Inform                2018.0
# 122              Divita G             EGEMS (Wash DC)                2016.0
# 99               Edrees H                    Drug Saf                2022.0
# ..                    ...                         ...                   ...
# 457                   NaN                         NaN                   NaN
# 468                   NaN                         NaN                   NaN
# 467                   NaN                         NaN                   NaN
# 456                   NaN                         NaN                   NaN
# 455                   NaN                         NaN                   NaN
#
#     data_criacao_pubmed id_pmc_pubmed id_nihms_pubmed  \
# 42           2021/05/27           NaN             NaN
# 164          2018/01/04    PMC5884681     NIHMS953299
# 85           2018/07/04           NaN             NaN
# 122          2016/09/30    PMC5019303             NaN
# 99           2022/05/17    PMC9112241             NaN
# ..                  ...           ...             ...
# 457                 NaN           NaN             NaN
# 468                 NaN           NaN             NaN
# 467                 NaN           NaN             NaN
# 456                 NaN           NaN             NaN
# 455                 NaN           NaN             NaN
#
#                      doi_pubmed  \
# 42           10.3233/SHTI210368
# 164                         NaN
# 85                          NaN
# 122     10.13063/2327-9214.1228
# 99   10.1007/s40264-022-01172-5
# ..                          ...
# 457                         NaN
# 468                         NaN
# 467                         NaN
# 456                         NaN
# 455                         NaN
#
#                                                                            titulo_documento_pubmed
# 42                    Visualising Patterns Associated with Adverse Drug Reactions in French Forums
# 164             MetaMap Lite in Excel: Biomedical Named-Entity Recognition for Non-Technical Users
# 85   Structuring Clinical Decision Support Rules for Drug Safety Using Natural Language Processing
# 122        v3NLP Framework: Tools to Build Applications for Extracting Concepts from Clinical Text
# 99                               Intelligent Telehealth in Pharmacovigilance: A Future Perspective
# ..                                                                                             ...
# 457                                                                                            NaN
# 468                                                                                            NaN
# 467                                                                                            NaN
# 456                                                                                            NaN
# 455                                                                                            NaN
#
# [548 rows x 70 columns]

# %%
#### de 561 para [554 rows x 554 columns] (antigo)
## new de 548 para 541
df_bases = df_bases.drop_duplicates(['titulo_documento', 'id_pubmed'], keep='last') 
print(df_bases)
# Out:
#                                                                                                        autores_scopus  \
# 42                                                                                                                NaN
# 122                                                                                                               NaN
# 99                                                                                                                NaN
# 174                                                                                                               NaN
# 181                                                                                                               NaN
# ..                                                                                                                ...
# 457  Nishioka S., Watanabe T., Asano M., Yamamoto T., Kawakami K., Yada S., Aramaki E., Yajima H., Kizaki H., Hori S.
# 468                                                 Yang J.C., Thygesen J.H., Werbeloff N., Hayes J.F., Osborn D.P.J.
# 467                                                                       Vo T.H., Nguyen N.T.K., Kha Q.H., Le N.Q.K.
# 456                                                                                                      Aronson J.K.
# 455                                              Portelli B., Scaboro S., Tonino R., Chersoni E., Santus E., Serra G.
#
#                                                                                                                   id_autores  \
# 42                                                                                                                       NaN
# 122                                                                                                                      NaN
# 99                                                                                                                       NaN
# 174                                                                                                                      NaN
# 181                                                                                                                      NaN
# ..                                                                                                                       ...
# 457  57665231500;57665866200;57666183300;57666504400;36484772100;57219665421;57203225161;57665866300;57607977600;8058209600;
# 468                                                              57202692614;42162169300;25522505100;36518630100;7101639320;
# 467                                                                         57671574900;57211071169;57224131231;57208281644;
# 456                                                                                                             55683060600;
# 455                                                 57219796263;57274686400;57704816900;57193697675;57189268006;10140344600;
#
#                                                                                                                                                titulo_documento  \
# 42                                                                                 visualising patterns associated with adverse drug reactions in french forums
# 122                                                                      v3nlp framework tools to build applications for extracting concepts from clinical text
# 99                                                                                             intelligent telehealth in pharmacovigilance a future perspective
# 174              artificial intelligence enabled social media analysis for pharmacovigilance of covid 19 vaccinations in the united kingdom observational study
# 181                                                            prediction of personal experience tweets of medication use via contextual word representations()
# ..                                                                                                                                                          ...
# 457  identification of hand foot syndrome from cancer patients’ blog posts bert based deep learning approach to detect potential adverse drug reaction symptoms
# 468                                              antipsychotic polypharmacy and adverse drug reactions among adults in a london mental health service 2008 2018
# 467                                                                      on the road to explainable ai in drug drug interactions prediction a systematic review
# 456                                                 artificial intelligence in pharmacovigilance an introduction to terms concepts applications and limitations
# 455                                           monitoring user opinions and side effects on covid 19 vaccines in the twittersphere infodemiology study of tweets
#
#         ano                                        titulo_fonte volume  \
# 42      NaN                                                 NaN    NaN
# 122     NaN                                                 NaN    NaN
# 99      NaN                                                 NaN    NaN
# 174     NaN                                                 NaN    NaN
# 181     NaN                                                 NaN    NaN
# ..      ...                                                 ...    ...
# 457  2022.0                                            PLoS ONE     17
# 468  2022.0                              Psychological Medicine    NaN
# 467  2022.0  Computational and Structural Biotechnology Journal     20
# 456  2022.0                                         Drug Safety     45
# 455  2022.0                Journal of Medical Internet Research     24
#
#     publicado numero_documento inicio_pagina fim_pagina  ...  \
# 42        NaN              NaN           NaN        NaN  ...
# 122       NaN              NaN           NaN        NaN  ...
# 99        NaN              NaN           NaN        NaN  ...
# 174       NaN              NaN           NaN        NaN  ...
# 181       NaN              NaN           NaN        NaN  ...
# ..        ...              ...           ...        ...  ...
# 457     5 May         e0267901           NaN        NaN  ...
# 468       NaN              NaN           NaN        NaN  ...
# 467       NaN              NaN          2112       2123  ...
# 456         5              NaN           407        418  ...
# 455         5           e35115           NaN        NaN  ...
#
#                                                                           autores_pubmed  \
# 42                                             Allam N, Audeh B, Jaulent MC, Bousquet C.
# 122  Divita G, Carter ME, Tran LT, Redd D, Zeng QT, Duvall S, Samore MH, Gundlapalli AV.
# 99                          Edrees H, Song W, Syrowatka A, Simona A, Amato MG, Bates DW.
# 174           Hussain Z, Sheikh Z, Tahir A, Dashtipour K, Gogate M, Sheikh A, Hussain A.
# 181                                               Jiang K, Chen T, Calix RA, Bernard GR.
# ..                                                                                   ...
# 457                                                                                  NaN
# 468                                                                                  NaN
# 467                                                                                  NaN
# 456                                                                                  NaN
# 455                                                                                  NaN
#
#                                                                                     citacao_pubmed  \
# 42                 Stud Health Technol Inform. 2021 May 27;281:1110-1111. doi: 10.3233/SHTI210368.
# 122        EGEMS (Wash DC). 2016 Aug 11;4(3):1228. doi: 10.13063/2327-9214.1228. eCollection 2016.
# 99            Drug Saf. 2022 May;45(5):449-458. doi: 10.1007/s40264-022-01172-5. Epub 2022 May 17.
# 174                      JMIR Public Health Surveill. 2022 May 27;8(5):e32543. doi: 10.2196/32543.
# 181  Annu Int Conf IEEE Eng Med Biol Soc. 2019 Jul;2019:6093-6096. doi: 10.1109/EMBC.2019.8856753.
# ..                                                                                             ...
# 457                                                                                            NaN
# 468                                                                                            NaN
# 467                                                                                            NaN
# 456                                                                                            NaN
# 455                                                                                            NaN
#
#     primeiro_autor_pubmed                   jornal_book_pubmed  \
# 42                Allam N           Stud Health Technol Inform
# 122              Divita G                      EGEMS (Wash DC)
# 99               Edrees H                             Drug Saf
# 174             Hussain Z          JMIR Public Health Surveill
# 181               Jiang K  Annu Int Conf IEEE Eng Med Biol Soc
# ..                    ...                                  ...
# 457                   NaN                                  NaN
# 468                   NaN                                  NaN
# 467                   NaN                                  NaN
# 456                   NaN                                  NaN
# 455                   NaN                                  NaN
#
#     ano_publicacao_pubmed data_criacao_pubmed id_pmc_pubmed id_nihms_pubmed  \
# 42                 2021.0          2021/05/27           NaN             NaN
# 122                2016.0          2016/09/30    PMC5019303             NaN
# 99                 2022.0          2022/05/17    PMC9112241             NaN
# 174                2022.0          2022/02/10    PMC9150729             NaN
# 181                2019.0          2020/01/18           NaN             NaN
# ..                    ...                 ...           ...             ...
# 457                   NaN                 NaN           NaN             NaN
# 468                   NaN                 NaN           NaN             NaN
# 467                   NaN                 NaN           NaN             NaN
# 456                   NaN                 NaN           NaN             NaN
# 455                   NaN                 NaN           NaN             NaN
#
#                      doi_pubmed  \
# 42           10.3233/SHTI210368
# 122     10.13063/2327-9214.1228
# 99   10.1007/s40264-022-01172-5
# 174               10.2196/32543
# 181   10.1109/EMBC.2019.8856753
# ..                          ...
# 457                         NaN
# 468                         NaN
# 467                         NaN
# 456                         NaN
# 455                         NaN
#
#                                                                                                                              titulo_documento_pubmed
# 42                                                                      Visualising Patterns Associated with Adverse Drug Reactions in French Forums
# 122                                                          v3NLP Framework: Tools to Build Applications for Extracting Concepts from Clinical Text
# 99                                                                                 Intelligent Telehealth in Pharmacovigilance: A Future Perspective
# 174  Artificial Intelligence-Enabled Social Media Analysis for Pharmacovigilance of COVID-19 Vaccinations in the United Kingdom: Observational Study
# 181                                                 Prediction of Personal Experience Tweets of Medication Use via Contextual Word Representations()
# ..                                                                                                                                               ...
# 457                                                                                                                                              NaN
# 468                                                                                                                                              NaN
# 467                                                                                                                                              NaN
# 456                                                                                                                                              NaN
# 455                                                                                                                                              NaN
#
# [541 rows x 70 columns]

# %%
df_bases.query('titulo_documento == "ai based language models powering drug discovery and development" ')[['eid','fonte','id_pubmed','quantidade_paginas_','titulo_documento']]
# Out:
#                     eid   fonte   id_pubmed  quantidade_paginas_  \
# 321  2-s2.0-85110540049  Scopus  34216835.0                 15.0
#
#                                                      titulo_documento
# 321  ai based language models powering drug discovery and development

# %%
df_bases.query('titulo_documento == "adverse drug event discovery using biomedical literature a big data neural network adventure" ')[['eid','fonte','id_pubmed','quantidade_paginas_','titulo_documento']]
# Out:
#                    eid   fonte  id_pubmed  quantidade_paginas_  \
# 82  2-s2.0-85047825131  Scopus        NaN                  1.0
#
#                                                                                 titulo_documento
# 82  adverse drug event discovery using biomedical literature a big data neural network adventure

# %%
df_bases.titulo_documento.value_counts()
# Out:
# visualising patterns associated with adverse drug reactions in french forums                                               1
# clinical natural language processing with deep learning                                                                    1
# named entity recognition from chinese adverse drug event reports with lexical feature based bilstm crf and tri training    1
# a disease inference method based on symptom extraction and bidirectional long short term memory networks                   1
# szte nlp clinical text analysis with named entity recognition                                                              1
#                                                                                                                           ..
# automatically detecting failures in natural language processing tools for online community text                            1
# on the creation of a clinical gold standard corpus in spanish mining adverse drug reactions                                1
# a novel text analysis platform for pharmacovigilance of clinical drugs                                                     1
# exploring brand name drug mentions on twitter for pharmacovigilance                                                        1
# monitoring user opinions and side effects on covid 19 vaccines in the twittersphere infodemiology study of tweets          1
# Name: titulo_documento, Length: 541, dtype: int64

# %%
df_bases.query('titulo_documento == "in silico analysis of autoimmune diseases and genetic relationships to vaccination against infectious diseases" ')[['eid','fonte','id_pubmed','quantidade_paginas_','titulo_documento']]
# Out:
#      eid   fonte   id_pubmed  quantidade_paginas_  \
# 141  NaN  PubMed  25486901.0                  NaN
#
#                                                                                                    titulo_documento
# 141  in silico analysis of autoimmune diseases and genetic relationships to vaccination against infectious diseases

# %%
df_bases.query('id_pubmed == 25486901.0 ')[['eid','fonte','id_pubmed','quantidade_paginas_','titulo_documento']]
# Out:
#                     eid   fonte   id_pubmed  quantidade_paginas_  \
# 141                 NaN  PubMed  25486901.0                  NaN
# 154  2-s2.0-84923927235  Scopus  25486901.0                  1.0
#
#                                                                                                    titulo_documento
# 141  in silico analysis of autoimmune diseases and genetic relationships to vaccination against infectious diseases
# 154            analysis of autoimmune diseases and genetic relationships to vaccination against infectious diseases

# %%
mask = (df_bases['id_pubmed'] == 25486901.0) & (df_bases['fonte'] == 'PubMed')
df_bases = df_bases.loc[~mask]

# %%
df_bases.query('titulo_documento == "in silico analysis of autoimmune diseases and genetic relationships to vaccination against infectious diseases" ')[['eid','fonte','id_pubmed','quantidade_paginas_','titulo_documento']]
# Out:
# Empty DataFrame
# Columns: [eid, fonte, id_pubmed, quantidade_paginas_, titulo_documento]
# Index: []

# %% [markdown]
# ### Exclusão de documentos por tipo
# ##### Tipos: "Conference Review","Editorial","Letter","Note"

# %%
# ver os tipos de documentos
df_bases.groupby(by=["tipo_documento"]).sum()
# Out:
#                         ano  quantidade_paginas  quantidade_citacoes  \
# tipo_documento
# Article            659295.0                 0.0               9267.0
# Book                 2014.0                 0.0                  5.0
# Book Chapter        14119.0                 0.0                 25.0
# Conference Paper   316480.0                11.0               1207.0
# Conference Review    6046.0              1942.0                  0.0
# Editorial            2015.0                 0.0                 12.0
# Note                 4039.0                 0.0                 22.0
# Review              50437.0                 0.0                707.0
#
#                    numeros_sequencia_molecular  texto_financiamento_4  \
# tipo_documento
# Article                                    0.0                    0.0
# Book                                       0.0                    0.0
# Book Chapter                               0.0                    0.0
# Conference Paper                           0.0                    0.0
# Conference Review                          0.0                    0.0
# Editorial                                  0.0                    0.0
# Note                                       0.0                    0.0
# Review                                     0.0                    0.0
#
#                    texto_financiamento_5  texto_financiamento_6  \
# tipo_documento
# Article                              0.0                    0.0
# Book                                 0.0                    0.0
# Book Chapter                         0.0                    0.0
# Conference Paper                     0.0                    0.0
# Conference Review                    0.0                    0.0
# Editorial                            0.0                    0.0
# Note                                 0.0                    0.0
# Review                               0.0                    0.0
#
#                    texto_financiamento_7  texto_financiamento_8  \
# tipo_documento
# Article                              0.0                    0.0
# Book                                 0.0                    0.0
# Book Chapter                         0.0                    0.0
# Conference Paper                     0.0                    0.0
# Conference Review                    0.0                    0.0
# Editorial                            0.0                    0.0
# Note                                 0.0                    0.0
# Review                               0.0                    0.0
#
#                    texto_financiamento_9  texto_financiamento_10  \
# tipo_documento
# Article                              0.0                     0.0
# Book                                 0.0                     0.0
# Book Chapter                         0.0                     0.0
# Conference Paper                     0.0                     0.0
# Conference Review                    0.0                     0.0
# Editorial                            0.0                     0.0
# Note                                 0.0                     0.0
# Review                               0.0                     0.0
#
#                    codigo_conferencia     id_pubmed  inicio_pagina_  \
# tipo_documento
# Article                           0.0  7.150187e+09        120805.0
# Book                              0.0  0.000000e+00             1.0
# Book Chapter                      0.0  0.000000e+00          2646.0
# Conference Paper           20444088.0  9.948066e+08         57346.0
# Conference Review            428626.0  0.000000e+00             1.0
# Editorial                         0.0  2.654701e+07           288.0
# Note                              0.0  2.986009e+07            73.0
# Review                            0.0  5.143306e+08          9792.0
#
#                    fim_pagina_  quantidade_paginas_  ano_publicacao_pubmed
# tipo_documento
# Article               122629.0               2151.0                    0.0
# Book                     264.0                264.0                    0.0
# Book Chapter            2738.0                 99.0                    0.0
# Conference Paper       58240.0               1051.0                    0.0
# Conference Review        132.0                134.0                    0.0
# Editorial                291.0                  4.0                    0.0
# Note                      86.0                 15.0                    0.0
# Review                  9967.0                200.0                    0.0

# %%
## antes - 553 para = 540 rows × 69 columns
## agora - 541 para = 534 rows × 70 columns
# retirar documentos: Conference Review, Editorial, letter e Note
# gerar plan geral e testar se os filtros funcionam só no scopus para maior assertividade

lista_tipo_doc = ["Conference Review","Editorial","Letter","Note"]

df_bases_filtrado = df_bases.query('tipo_documento != @lista_tipo_doc ') 
df_bases_filtrado
# Out:
#                                                                                                        autores_scopus  \
# 42                                                                                                                NaN
# 122                                                                                                               NaN
# 99                                                                                                                NaN
# 174                                                                                                               NaN
# 181                                                                                                               NaN
# ..                                                                                                                ...
# 457  Nishioka S., Watanabe T., Asano M., Yamamoto T., Kawakami K., Yada S., Aramaki E., Yajima H., Kizaki H., Hori S.
# 468                                                 Yang J.C., Thygesen J.H., Werbeloff N., Hayes J.F., Osborn D.P.J.
# 467                                                                       Vo T.H., Nguyen N.T.K., Kha Q.H., Le N.Q.K.
# 456                                                                                                      Aronson J.K.
# 455                                              Portelli B., Scaboro S., Tonino R., Chersoni E., Santus E., Serra G.
#
#                                                                                                                   id_autores  \
# 42                                                                                                                       NaN
# 122                                                                                                                      NaN
# 99                                                                                                                       NaN
# 174                                                                                                                      NaN
# 181                                                                                                                      NaN
# ..                                                                                                                       ...
# 457  57665231500;57665866200;57666183300;57666504400;36484772100;57219665421;57203225161;57665866300;57607977600;8058209600;
# 468                                                              57202692614;42162169300;25522505100;36518630100;7101639320;
# 467                                                                         57671574900;57211071169;57224131231;57208281644;
# 456                                                                                                             55683060600;
# 455                                                 57219796263;57274686400;57704816900;57193697675;57189268006;10140344600;
#
#                                                                                                                                                titulo_documento  \
# 42                                                                                 visualising patterns associated with adverse drug reactions in french forums
# 122                                                                      v3nlp framework tools to build applications for extracting concepts from clinical text
# 99                                                                                             intelligent telehealth in pharmacovigilance a future perspective
# 174              artificial intelligence enabled social media analysis for pharmacovigilance of covid 19 vaccinations in the united kingdom observational study
# 181                                                            prediction of personal experience tweets of medication use via contextual word representations()
# ..                                                                                                                                                          ...
# 457  identification of hand foot syndrome from cancer patients’ blog posts bert based deep learning approach to detect potential adverse drug reaction symptoms
# 468                                              antipsychotic polypharmacy and adverse drug reactions among adults in a london mental health service 2008 2018
# 467                                                                      on the road to explainable ai in drug drug interactions prediction a systematic review
# 456                                                 artificial intelligence in pharmacovigilance an introduction to terms concepts applications and limitations
# 455                                           monitoring user opinions and side effects on covid 19 vaccines in the twittersphere infodemiology study of tweets
#
#         ano                                        titulo_fonte volume  \
# 42      NaN                                                 NaN    NaN
# 122     NaN                                                 NaN    NaN
# 99      NaN                                                 NaN    NaN
# 174     NaN                                                 NaN    NaN
# 181     NaN                                                 NaN    NaN
# ..      ...                                                 ...    ...
# 457  2022.0                                            PLoS ONE     17
# 468  2022.0                              Psychological Medicine    NaN
# 467  2022.0  Computational and Structural Biotechnology Journal     20
# 456  2022.0                                         Drug Safety     45
# 455  2022.0                Journal of Medical Internet Research     24
#
#     publicado numero_documento inicio_pagina fim_pagina  ...  \
# 42        NaN              NaN           NaN        NaN  ...
# 122       NaN              NaN           NaN        NaN  ...
# 99        NaN              NaN           NaN        NaN  ...
# 174       NaN              NaN           NaN        NaN  ...
# 181       NaN              NaN           NaN        NaN  ...
# ..        ...              ...           ...        ...  ...
# 457     5 May         e0267901           NaN        NaN  ...
# 468       NaN              NaN           NaN        NaN  ...
# 467       NaN              NaN          2112       2123  ...
# 456         5              NaN           407        418  ...
# 455         5           e35115           NaN        NaN  ...
#
#                                                                           autores_pubmed  \
# 42                                             Allam N, Audeh B, Jaulent MC, Bousquet C.
# 122  Divita G, Carter ME, Tran LT, Redd D, Zeng QT, Duvall S, Samore MH, Gundlapalli AV.
# 99                          Edrees H, Song W, Syrowatka A, Simona A, Amato MG, Bates DW.
# 174           Hussain Z, Sheikh Z, Tahir A, Dashtipour K, Gogate M, Sheikh A, Hussain A.
# 181                                               Jiang K, Chen T, Calix RA, Bernard GR.
# ..                                                                                   ...
# 457                                                                                  NaN
# 468                                                                                  NaN
# 467                                                                                  NaN
# 456                                                                                  NaN
# 455                                                                                  NaN
#
#                                                                                     citacao_pubmed  \
# 42                 Stud Health Technol Inform. 2021 May 27;281:1110-1111. doi: 10.3233/SHTI210368.
# 122        EGEMS (Wash DC). 2016 Aug 11;4(3):1228. doi: 10.13063/2327-9214.1228. eCollection 2016.
# 99            Drug Saf. 2022 May;45(5):449-458. doi: 10.1007/s40264-022-01172-5. Epub 2022 May 17.
# 174                      JMIR Public Health Surveill. 2022 May 27;8(5):e32543. doi: 10.2196/32543.
# 181  Annu Int Conf IEEE Eng Med Biol Soc. 2019 Jul;2019:6093-6096. doi: 10.1109/EMBC.2019.8856753.
# ..                                                                                             ...
# 457                                                                                            NaN
# 468                                                                                            NaN
# 467                                                                                            NaN
# 456                                                                                            NaN
# 455                                                                                            NaN
#
#     primeiro_autor_pubmed                   jornal_book_pubmed  \
# 42                Allam N           Stud Health Technol Inform
# 122              Divita G                      EGEMS (Wash DC)
# 99               Edrees H                             Drug Saf
# 174             Hussain Z          JMIR Public Health Surveill
# 181               Jiang K  Annu Int Conf IEEE Eng Med Biol Soc
# ..                    ...                                  ...
# 457                   NaN                                  NaN
# 468                   NaN                                  NaN
# 467                   NaN                                  NaN
# 456                   NaN                                  NaN
# 455                   NaN                                  NaN
#
#     ano_publicacao_pubmed data_criacao_pubmed id_pmc_pubmed id_nihms_pubmed  \
# 42                 2021.0          2021/05/27           NaN             NaN
# 122                2016.0          2016/09/30    PMC5019303             NaN
# 99                 2022.0          2022/05/17    PMC9112241             NaN
# 174                2022.0          2022/02/10    PMC9150729             NaN
# 181                2019.0          2020/01/18           NaN             NaN
# ..                    ...                 ...           ...             ...
# 457                   NaN                 NaN           NaN             NaN
# 468                   NaN                 NaN           NaN             NaN
# 467                   NaN                 NaN           NaN             NaN
# 456                   NaN                 NaN           NaN             NaN
# 455                   NaN                 NaN           NaN             NaN
#
#                      doi_pubmed  \
# 42           10.3233/SHTI210368
# 122     10.13063/2327-9214.1228
# 99   10.1007/s40264-022-01172-5
# 174               10.2196/32543
# 181   10.1109/EMBC.2019.8856753
# ..                          ...
# 457                         NaN
# 468                         NaN
# 467                         NaN
# 456                         NaN
# 455                         NaN
#
#                                                                                                                              titulo_documento_pubmed
# 42                                                                      Visualising Patterns Associated with Adverse Drug Reactions in French Forums
# 122                                                          v3NLP Framework: Tools to Build Applications for Extracting Concepts from Clinical Text
# 99                                                                                 Intelligent Telehealth in Pharmacovigilance: A Future Perspective
# 174  Artificial Intelligence-Enabled Social Media Analysis for Pharmacovigilance of COVID-19 Vaccinations in the United Kingdom: Observational Study
# 181                                                 Prediction of Personal Experience Tweets of Medication Use via Contextual Word Representations()
# ..                                                                                                                                               ...
# 457                                                                                                                                              NaN
# 468                                                                                                                                              NaN
# 467                                                                                                                                              NaN
# 456                                                                                                                                              NaN
# 455                                                                                                                                              NaN
#
# [534 rows x 70 columns]

# %% [markdown]
# ### Exclusão de documentos com menos de 4 páginas

# %% [raw]
# # Aqui não será necessário exclusão, pois a base pubmed nao tem páginas e do scopus já foi excluído acima
# ## Anter eram 540 ficando 515 rows ** verificar esta qtde****
# # Até o momento 'novo', temos 534

# %%
# Ordenando 
df_bases_filtrado = df_bases_filtrado.sort_values(['titulo_documento','id_pubmed'])
df_bases_filtrado
# Out:
#                                                          autores_scopus  \
# 66              Henry S., Buchan K., Filannino M., Stubbs A., Uzuner O.
# 39   Wu Y., Denny J.C., Rosenbloom S.T., Miller R.A., Giuse D.A., Xu H.
# 418                                                 Sabra S., Sabeeh V.
# 214                  Danger R., Segura-Bedmar I., Martínez P., Rosso P.
# 368                         Qiu Y., Zhang Y., Deng Y., Liu S., Zhang W.
# ..                                                                  ...
# 42                                                                  NaN
# 156               Chase H.S., Kaufman D.R., Johnson S.B., Mendonca E.A.
# 298                                           Priyadarshi A., Saha S.K.
# 347                                          Jiang J., Guan Y., Zhao C.
# 534                          Gasmi K., Torjmen-Khemakhem M., Jemaa M.B.
#
#                                                                id_autores  \
# 66            57195512541;57194652773;25633782800;56086371300;6507268190;
# 39   55645924700;7005252620;7003853908;8093690100;6701504476;55493876700;
# 418                                              57189298972;57202214511;
# 214                        55920998300;35303400800;7202906176;8960238100;
# 368          57216565394;57218471527;57219231397;57210886728;57190273716;
# ..                                                                    ...
# 42                                                                    NaN
# 156                         7103097287;34770630900;7406330166;7004308859;
# 298                                              57212489282;36937742800;
# 347                                   56376858400;7202924009;57189217850;
# 534                                   36662245700;23393830500;6507198229;
#
#                                                                                                                          titulo_documento  \
# 66                                    2018 n2c2 shared task on adverse drug events and medication extraction in electronic health records
# 39           a comparative study of current clinical natural language processing systems on handling abbreviations in discharge summaries
# 418                                                          a comparative study of n gram and skip gram for clinical concepts extraction
# 214                                                     a comparison of machine learning techniques for detection of drug target articles
# 368                                                   a comprehensive review of computational methods for drug drug interaction detection
# ..                                                                                                                                    ...
# 42                                                           visualising patterns associated with adverse drug reactions in french forums
# 156                                           voice capture of medical residents' clinical information needs during an inpatient rotation
# 298                                  web information extraction for finding remedy based on a patient authored text a study on homeopathy
# 347                                            wi enre in clef ehealth evaluation lab 2015 clinical named entity recognition based on crf
# 534  word indexing versus conceptual indexing in medical image retrieval (redcad participation at imageclef medical image retrieval 2012)
#
#         ano  \
# 66   2020.0
# 39   2012.0
# 418  2020.0
# 214  2010.0
# 368  2021.0
# ..      ...
# 42      NaN
# 156  2009.0
# 298  2020.0
# 347  2015.0
# 534  2012.0
#
#                                                                                                        titulo_fonte  \
# 66                                                          Journal of the American Medical Informatics Association
# 39                                           AMIA ... Annual Symposium proceedings / AMIA Symposium. AMIA Symposium
# 418  Proceedings - 2020 International Conference on Computational Science and Computational Intelligence, CSCI 2020
# 214                                                                               Journal of Biomedical Informatics
# 368                                               IEEE/ACM Transactions on Computational Biology and Bioinformatics
# ..                                                                                                              ...
# 42                                                                                                              NaN
# 156                                                         Journal of the American Medical Informatics Association
# 298                                              Network Modeling Analysis in Health Informatics and Bioinformatics
# 347                                                                                       CEUR Workshop Proceedings
# 534                                                                                       CEUR Workshop Proceedings
#
#     volume publicado numero_documento inicio_pagina fim_pagina  ...  \
# 66      27         1              NaN             3         12  ...
# 39    2012       NaN              NaN           997       1003  ...
# 418    NaN       NaN          9458183           807        812  ...
# 214     43         6              NaN           902        913  ...
# 368    NaN       NaN              NaN           NaN        NaN  ...
# ..     ...       ...              ...           ...        ...  ...
# 42     NaN       NaN              NaN           NaN        NaN  ...
# 156     16         3              NaN           387        394  ...
# 298      9         1                9           NaN        NaN  ...
# 347   1391       NaN              NaN           NaN        NaN  ...
# 534   1178       NaN              NaN           NaN        NaN  ...
#
#                                 autores_pubmed  \
# 66                                         NaN
# 39                                         NaN
# 418                                        NaN
# 214                                        NaN
# 368                                        NaN
# ..                                         ...
# 42   Allam N, Audeh B, Jaulent MC, Bousquet C.
# 156                                        NaN
# 298                                        NaN
# 347                                        NaN
# 534                                        NaN
#
#                                                                       citacao_pubmed  \
# 66                                                                               NaN
# 39                                                                               NaN
# 418                                                                              NaN
# 214                                                                              NaN
# 368                                                                              NaN
# ..                                                                               ...
# 42   Stud Health Technol Inform. 2021 May 27;281:1110-1111. doi: 10.3233/SHTI210368.
# 156                                                                              NaN
# 298                                                                              NaN
# 347                                                                              NaN
# 534                                                                              NaN
#
#     primeiro_autor_pubmed          jornal_book_pubmed ano_publicacao_pubmed  \
# 66                    NaN                         NaN                   NaN
# 39                    NaN                         NaN                   NaN
# 418                   NaN                         NaN                   NaN
# 214                   NaN                         NaN                   NaN
# 368                   NaN                         NaN                   NaN
# ..                    ...                         ...                   ...
# 42                Allam N  Stud Health Technol Inform                2021.0
# 156                   NaN                         NaN                   NaN
# 298                   NaN                         NaN                   NaN
# 347                   NaN                         NaN                   NaN
# 534                   NaN                         NaN                   NaN
#
#     data_criacao_pubmed id_pmc_pubmed id_nihms_pubmed          doi_pubmed  \
# 66                  NaN           NaN             NaN                 NaN
# 39                  NaN           NaN             NaN                 NaN
# 418                 NaN           NaN             NaN                 NaN
# 214                 NaN           NaN             NaN                 NaN
# 368                 NaN           NaN             NaN                 NaN
# ..                  ...           ...             ...                 ...
# 42           2021/05/27           NaN             NaN  10.3233/SHTI210368
# 156                 NaN           NaN             NaN                 NaN
# 298                 NaN           NaN             NaN                 NaN
# 347                 NaN           NaN             NaN                 NaN
# 534                 NaN           NaN             NaN                 NaN
#
#                                                           titulo_documento_pubmed
# 66                                                                            NaN
# 39                                                                            NaN
# 418                                                                           NaN
# 214                                                                           NaN
# 368                                                                           NaN
# ..                                                                            ...
# 42   Visualising Patterns Associated with Adverse Drug Reactions in French Forums
# 156                                                                           NaN
# 298                                                                           NaN
# 347                                                                           NaN
# 534                                                                           NaN
#
# [534 rows x 70 columns]

# %% [markdown]
# ### Exclusão de documentos com outros critérios

# %%
## verificar pq excluo estes, por enquanto nao excluir ##777

# %% [raw]
# ## verificar se este titulo nao foi tratado e tals
# #df_bases.query('id_pubmed== 28664200')[['titulo_documento','fonte','id_pubmed','issn_scopus','doi_scopus','doi_pubmed']]

# %% [raw]
# #df_bases_filtrado.query('id_pubmed== 28664200')

# %% [markdown]
# #df_bases_filtrado.query('titulo_documento== "extraction of adverse drug effects from clinical records"')

# %% [raw]
# #df_bases.query('titulo_documento== "extraction of adverse drug effects from clinical records"')[['titulo_documento','isbn','fonte','id_pubmed','issn_scopus','doi_scopus','doi_pubmed']]

# %% [raw]
# ## nao excluir + por enquanto
# ## estranho q parece q está excluindo 2 registros
#
# # novo, ficando 531 rows × 70 columns
# df_remove = df_bases_filtrado.loc[
#     (df_bases_filtrado['id_pubmed'] == 28664200) & (df_bases_filtrado['doi_pubmed'] == '10.1007/978-3-319-48472-3_43') |
#     (df_bases_filtrado['doi_scopus'] == '10.3233/978-1-60750-588-4-739') & (df_bases_filtrado['titulo_documento'] == 'extraction of adverse drug effects from clinical records')
# ]
#
# df_bases_filtrado = df_bases_filtrado.drop(df_remove.index)
# df_bases_filtrado

# %% [markdown]
# ## Ajustes de bases indexadas final

# %%
# Criar colunas
df_bases_filtrado['documentos_6+']=0 # variavel que marca os documentos + tops para ler
df_bases_filtrado['documentos_94+']=0 # variavel que marca os documentos + tops para ler
df_bases_filtrado['pdf_baixado']=0 #

df_bases_filtrado['leitura_resumo']=0 # 0 nao foi lido e 1 foi lido 
df_bases_filtrado['leitura_conclusao']=0 # 0 nao foi lido e 1 foi lido
df_bases_filtrado['leitura_completa']=0 # 0 nao foi lido e 1 foi lido
df_bases_filtrado['resumo_traduzido']=None
df_bases_filtrado['conclusao_traduzida']=None

# colunas para marcar estudo posterior para conceitos
df_bases_filtrado['conceituar_metamap']=0 # variavel que marca documento para rever conceito
df_bases_filtrado['conceituar_farmacovigilancia']=0 # variavel que marca documento para rever conceito
df_bases_filtrado['conceituar_Reacao_adversa_medicamentos_RAM']=0 # variavel que marca documento para rever conceito
df_bases_filtrado['conceituar_reconhecimento_entidades_nomeadas_REN']=0 # variavel que marca documento para rever conceito
df_bases_filtrado['conceituar_UMLS']=0
df_bases_filtrado['conceituar_metamap_data_file_builder_DFB']=0
df_bases_filtrado['conceituar_ferramenta_lexicos_LVG']=0
df_bases_filtrado['conceituar_MetamorphoSys']=0
df_bases_filtrado['conceituar_NLP']=0
df_bases_filtrado['conceituar_outros']=None
df_bases_filtrado['observacao']=None
df_bases_filtrado['sincronizado_mendeley']=0
df_bases_filtrado['data_leitura_resumo']=None
df_bases_filtrado['data_leitura_completa']=None
df_bases_filtrado['palavras_chaves_titulo']=None # variavel para receber as palavras + importantes em um documento
df_bases_filtrado['palavras_chaves_resumo']=None # variavel para receber as palavras + importantes em um documento

# %%
# Colocar estes campos no dataframe final filtrado

df_bases_filtrado.loc[
    (df_bases_filtrado['titulo_documento'].str.contains('twitter'))|
    (df_bases_filtrado['titulo_documento'].str.contains('metamap'))|
    (df_bases_filtrado['titulo_documento'].str.contains('NLP'))|
    (df_bases_filtrado['titulo_documento'].str.contains('social media'))|
    (df_bases_filtrado['titulo_documento'].str.contains('social network'))|
    (df_bases_filtrado['titulo_documento'].str.contains('natural language processing')),'palavras_chaves_titulo'] = "twitter|metamap|nlp"

df_bases_filtrado.query('palavras_chaves_titulo=="twitter|metamap|nlp"')['titulo_documento'].count()
# Out:
# 129

# %%
df_bases_filtrado.loc[
    (df_bases_filtrado['resumo'].str.contains('twitter'))|
    (df_bases_filtrado['resumo'].str.contains('metamap'))|
    (df_bases_filtrado['resumo'].str.contains('NLP'))|
    (df_bases_filtrado['resumo'].str.contains('social media'))|
    (df_bases_filtrado['resumo'].str.contains('social network'))|
    (df_bases_filtrado['resumo'].str.contains('natural language processing')),'palavras_chaves_resumo'] = "twitter|metamap|nlp"


df_bases_filtrado.query('palavras_chaves_resumo=="twitter|metamap|nlp"')['resumo'].count()
# Out:
# 390

# %% [markdown]
# ## Traduzir conteúdo de colunas
#
# <b>Ajustes a serem realizados com a biblioteca de tradução</b>
# 1. pip install google_trans_new
# 1. ir no local da instalação e ajustar o arquivo (..\Python\Lib\site-packages\google_trans_new) "google_trans_new.py"
# 1. alterar linha 151, **de**:  response = (decoded_line + ']') **para**: response = (decoded_line + '')
# 1. reiniciar o kernel do Python/Jupyter
#
# <br>
#
# **Referências**
# <br>
# https://thewebdev.info/2022/04/17/how-to-fix-googletrans-stopped-working-with-error-nonetype-object-has-no-attribute-group-with-python/ <br>
# https://github.com/lushan88a/google_trans_new/issues/46 <br>
# https://www.linkedin.com/pulse/traduzindo-dados-pandasdataframe-com-google-translate-romerito-morais/?originalSubdomain=pt (testar este)

# %%
translator = google_translator()

# %%
df_bases_filtrado['titulo_documento_traduzido']=df_bases_filtrado['titulo_documento'].apply(lambda x: translator.translate(x,lang_tgt='pt'))

# %%
# %%time
df_bases_filtrado['titulo_documento_pubmed_traduzido']=df_bases_filtrado['titulo_documento_pubmed'].apply(lambda x: translator.translate(x,lang_tgt='pt'))

# %%
# %%time
df_bases_filtrado['resumo_traduzido_google_translator']=df_bases_filtrado['resumo'].apply(lambda x: translator.translate(x,lang_tgt='pt'))

# %%
df_bases_filtrado[['leitura_conclusao']]

# %% [markdown]
# ## Reanalisar bases

# %%
print('Verificando tipos e se tem dados nulos')
df_bases_filtrado.info()
# Out:
# Verificando tipos e se tem dados nulos
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 531 entries, 66 to 534
# Data columns (total 94 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   autores_scopus                                    515 non-null    object
#  1   id_autores                                        515 non-null    object
#  2   titulo_documento                                  531 non-null    object
#  3   ano                                               515 non-null    float64
#  4   titulo_fonte                                      515 non-null    object
#  5   volume                                            437 non-null    object
#  6   publicado                                         225 non-null    object
#  7   numero_documento                                  139 non-null    object
#  8   inicio_pagina                                     385 non-null    object
#  9   fim_pagina                                        376 non-null    object
#  10  quantidade_paginas                                1 non-null      float64
#  11  quantidade_citacoes                               440 non-null    float64
#  12  doi_scopus                                        422 non-null    object
#  13  link_scopus                                       515 non-null    object
#  14  afiliacoes                                        514 non-null    object
#  15  autores_com_filiacoes                             515 non-null    object
#  16  resumo                                            515 non-null    object
#  17  palavras_chaves_autor                             364 non-null    object
#  18  palavras_chave_index                              468 non-null    object
#  19  numeros_sequencia_molecular                       0 non-null      float64
#  20  chemicals_cas                                     114 non-null    object
#  21  nomes_comerciais                                  20 non-null     object
#  22  fabricantes                                       2 non-null      category
#  23  detalhes_financiamento                            267 non-null    object
#  24  texto_financiamento_1                             242 non-null    object
#  25  texto_financiamento_2                             27 non-null     object
#  26  texto_financiamento_3                             3 non-null      object
#  27  texto_financiamento_4                             0 non-null      float64
#  28  texto_financiamento_5                             0 non-null      float64
#  29  texto_financiamento_6                             0 non-null      float64
#  30  texto_financiamento_7                             0 non-null      float64
#  31  texto_financiamento_8                             0 non-null      float64
#  32  texto_financiamento_9                             0 non-null      float64
#  33  texto_financiamento_10                            0 non-null      float64
#  34  referencias                                       461 non-null    object
#  35  endereco_correspondencia                          413 non-null    object
#  36  editores                                          90 non-null     object
#  37  patrocinadores                                    47 non-null     object
#  38  editor                                            416 non-null    object
#  39  nome_conferencia                                  151 non-null    object
#  40  data_conferencia                                  151 non-null    object
#  41  local_conferencia                                 28 non-null     object
#  42  codigo_conferencia                                141 non-null    float64
#  43  issn_scopus                                       449 non-null    object
#  44  isbn                                              126 non-null    object
#  45  coden                                             190 non-null    object
#  46  id_pubmed                                         333 non-null    float64
#  47  idioma_original                                   515 non-null    category
#  48  titulo_abreviado_fonte                            514 non-null    object
#  49  tipo_documento                                    515 non-null    object
#  50  etapa_publicacao                                  515 non-null    category
#  51  acesso_livre                                      251 non-null    category
#  52  fonte                                             531 non-null    object
#  53  eid                                               515 non-null    object
#  54  doi                                               436 non-null    object
#  55  titulo_documento_scopus                           515 non-null    object
#  56  inicio_pagina_                                    515 non-null    float64
#  57  fim_pagina_                                       515 non-null    float64
#  58  status_pagina                                     515 non-null    object
#  59  quantidade_paginas_                               515 non-null    float64
#  60  autores_pubmed                                    16 non-null     object
#  61  citacao_pubmed                                    16 non-null     object
#  62  primeiro_autor_pubmed                             16 non-null     object
#  63  jornal_book_pubmed                                16 non-null     category
#  64  ano_publicacao_pubmed                             16 non-null     float64
#  65  data_criacao_pubmed                               16 non-null     object
#  66  id_pmc_pubmed                                     12 non-null     object
#  67  id_nihms_pubmed                                   1 non-null      object
#  68  doi_pubmed                                        14 non-null     object
#  69  titulo_documento_pubmed                           16 non-null     object
#  70  documentos_6+                                     531 non-null    int64
#  71  documentos_94+                                    531 non-null    int64
#  72  pdf_baixado                                       531 non-null    int64
#  73  leitura_resumo                                    531 non-null    int64
#  74  leitura_conclusao                                 531 non-null    int64
#  75  leitura_completa                                  531 non-null    int64
#  76  resumo_traduzido                                  0 non-null      object
#  77  conclusao_traduzida                               0 non-null      object
#  78  conceituar_metamap                                531 non-null    int64
#  79  conceituar_farmacovigilancia                      531 non-null    int64
#  80  conceituar_Reacao_adversa_medicamentos_RAM        531 non-null    int64
#  81  conceituar_reconhecimento_entidades_nomeadas_REN  531 non-null    int64
#  82  conceituar_UMLS                                   531 non-null    int64
#  83  conceituar_metamap_data_file_builder_DFB          531 non-null    int64
#  84  conceituar_ferramenta_lexicos_LVG                 531 non-null    int64
#  85  conceituar_MetamorphoSys                          531 non-null    int64
#  86  conceituar_NLP                                    531 non-null    int64
#  87  conceituar_outros                                 0 non-null      object
#  88  observacao                                        0 non-null      object
#  89  sincronizado_mendeley                             531 non-null    int64
#  90  data_leitura_resumo                               0 non-null      object
#  91  data_leitura_completa                             0 non-null      object
#  92  palavras_chaves_titulo                            129 non-null    object
#  93  palavras_chaves_resumo                            390 non-null    object
# dtypes: category(5), float64(17), int64(16), object(56)
# memory usage: 379.2+ KB

# %%
print(df_bases_filtrado.nunique()) ## ver como aparecer todoas as colunas
# Out:
# autores_scopus            507
# id_autores                503
# titulo_documento          531
# ano                        23
# titulo_fonte              186
#                          ...
# sincronizado_mendeley       1
# data_leitura_resumo         0
# data_leitura_completa       0
# palavras_chaves_titulo      1
# palavras_chaves_resumo      1
# Length: 94, dtype: int64

# %%
df_bases_filtrado.isnull().sum()
# Out:
# autores_scopus             16
# id_autores                 16
# titulo_documento            0
# ano                        16
# titulo_fonte               16
#                          ...
# sincronizado_mendeley       0
# data_leitura_resumo       531
# data_leitura_completa     531
# palavras_chaves_titulo    402
# palavras_chaves_resumo    141
# Length: 94, dtype: int64

# %%
print('Resumo Estatístico de Campos Numéricos')
## selecionar as colunas necessárias
df_bases_filtrado.describe()
# Out:
# Resumo Estatístico de Campos Numéricos
#                ano  quantidade_paginas  quantidade_citacoes  \
# count   515.000000                 1.0           440.000000
# mean   2016.151456                11.0            25.227273
# std       4.480434                 NaN            75.808163
# min    1992.000000                11.0             1.000000
# 25%    2014.000000                11.0             3.000000
# 50%    2017.000000                11.0            10.000000
# 75%    2020.000000                11.0            25.000000
# max    2022.000000                11.0          1339.000000
#
#        numeros_sequencia_molecular  texto_financiamento_4  \
# count                          0.0                    0.0
# mean                           NaN                    NaN
# std                            NaN                    NaN
# min                            NaN                    NaN
# 25%                            NaN                    NaN
# 50%                            NaN                    NaN
# 75%                            NaN                    NaN
# max                            NaN                    NaN
#
#        texto_financiamento_5  texto_financiamento_6  texto_financiamento_7  \
# count                    0.0                    0.0                    0.0
# mean                     NaN                    NaN                    NaN
# std                      NaN                    NaN                    NaN
# min                      NaN                    NaN                    NaN
# 25%                      NaN                    NaN                    NaN
# 50%                      NaN                    NaN                    NaN
# 75%                      NaN                    NaN                    NaN
# max                      NaN                    NaN                    NaN
#
#        texto_financiamento_8  texto_financiamento_9  ...  conceituar_metamap  \
# count                    0.0                    0.0  ...               531.0
# mean                     NaN                    NaN  ...                 0.0
# std                      NaN                    NaN  ...                 0.0
# min                      NaN                    NaN  ...                 0.0
# 25%                      NaN                    NaN  ...                 0.0
# 50%                      NaN                    NaN  ...                 0.0
# 75%                      NaN                    NaN  ...                 0.0
# max                      NaN                    NaN  ...                 0.0
#
#        conceituar_farmacovigilancia  \
# count                         531.0
# mean                            0.0
# std                             0.0
# min                             0.0
# 25%                             0.0
# 50%                             0.0
# 75%                             0.0
# max                             0.0
#
#        conceituar_Reacao_adversa_medicamentos_RAM  \
# count                                       531.0
# mean                                          0.0
# std                                           0.0
# min                                           0.0
# 25%                                           0.0
# 50%                                           0.0
# 75%                                           0.0
# max                                           0.0
#
#        conceituar_reconhecimento_entidades_nomeadas_REN  conceituar_UMLS  \
# count                                             531.0            531.0
# mean                                                0.0              0.0
# std                                                 0.0              0.0
# min                                                 0.0              0.0
# 25%                                                 0.0              0.0
# 50%                                                 0.0              0.0
# 75%                                                 0.0              0.0
# max                                                 0.0              0.0
#
#        conceituar_metamap_data_file_builder_DFB  \
# count                                     531.0
# mean                                        0.0
# std                                         0.0
# min                                         0.0
# 25%                                         0.0
# 50%                                         0.0
# 75%                                         0.0
# max                                         0.0
#
#        conceituar_ferramenta_lexicos_LVG  conceituar_MetamorphoSys  \
# count                              531.0                     531.0
# mean                                 0.0                       0.0
# std                                  0.0                       0.0
# min                                  0.0                       0.0
# 25%                                  0.0                       0.0
# 50%                                  0.0                       0.0
# 75%                                  0.0                       0.0
# max                                  0.0                       0.0
#
#        conceituar_NLP  sincronizado_mendeley
# count           531.0                  531.0
# mean              0.0                    0.0
# std               0.0                    0.0
# min               0.0                    0.0
# 25%               0.0                    0.0
# 50%               0.0                    0.0
# 75%               0.0                    0.0
# max               0.0                    0.0
#
# [8 rows x 33 columns]

# %% [markdown]
# ## Visualizações de bases

# %% [markdown]
# ### Analisando documentos por Ano

# %% [markdown]
# ### Nuvem de Palavras

# %% [markdown]
# #### Nuvem de Palavras dos Títulos

# %%
palavras_titulo_bases  = df_bases_filtrado['titulo_documento'].str.lower()
palavras_titulo_bases

# %%
wordcloud_palavras_titulo_bases = " ".join(s for s in palavras_titulo_bases)

print(f'Quantidade de palavras no corpus: {len(wordcloud_palavras_titulo_bases)} e seu tipo atual é {type(wordcloud_palavras_titulo_bases)}')

wordcloud_titulo_bases = WordCloud(stopwords=stopwords,
                      background_color='black', width=1600,                            
                      height=800).generate(wordcloud_palavras_titulo_bases)

# %%
path_image = '../image/'

titulo = 'Nuvem de Palavras'
#eixo_x = ''
#eixo_y = ''
image = path_image+'wordcloud_titulo_bases'
extensao_arquivo = '.pdf'

#Gráfico
fig, ax = plt.subplots(figsize=(16,8))            
ax.imshow(wordcloud_titulo_bases, interpolation='bilinear')
ax.set_axis_off()         

#legendas
#ax.legend(title='Legenda', loc=4, fontsize=9)
ax.set_title(titulo, fontsize=18)
#ax.set_xlabel(eixo_x, fontsize=9)
#ax.set_ylabel(eixo_y, fontsize=9)

#salvar imagens
plt.savefig(image+extensao_arquivo) #, format='pdf', dpi=300, transparent=True)
plt.tight_layout() 
plt.show()

# %% [markdown]
# #### Nuvem de Palavras dos Títulos em português

# %%
stopwords_pt = nltk.corpus.stopwords.words('portuguese')
print(stopwords_pt)

# %%
palavras_titulo_bases_pt  = df_bases_filtrado['titulo_documento_traduzido'].str.lower()
palavras_titulo_bases_pt

# %%
wordcloud_palavras_titulo_pt = " ".join(s for s in palavras_titulo_bases_pt)

print(f'Quantidade de palavras no corpus: {len(wordcloud_palavras_titulo_bases)} e seu tipo atual é {type(wordcloud_palavras_titulo_bases)}')

wordcloud_titulo_pt = WordCloud(stopwords=stopwords_pt,
                      background_color='black', width=1600,                            
                      height=800).generate(wordcloud_palavras_titulo_pt)

# %%
path_image = '../image/'

titulo = 'Nuvem de Palavras'
#eixo_x = ''
#eixo_y = ''
image = path_image+'wordcloud_titulo_pt'
extensao_arquivo = '.pdf'

#Gráfico
fig, ax = plt.subplots(figsize=(16,8))            
ax.imshow(wordcloud_titulo_pt, interpolation='bilinear')
ax.set_axis_off()         

#legendas
#ax.legend(title='Legenda', loc=4, fontsize=9)
ax.set_title(titulo, fontsize=18)
#ax.set_xlabel(eixo_x, fontsize=9)
#ax.set_ylabel(eixo_y, fontsize=9)

#salvar imagens
plt.savefig(image+extensao_arquivo) #, format='pdf', dpi=300, transparent=True)
plt.tight_layout() 
plt.show()

# %% [markdown]
# #### Nuvem de Palavras dos Resumos em português

# %% [markdown]
# ## Exportação de arquivo

# %%
df_bases_filtrado.columns

# %%
## Gerar planilha com colunas especificas
#resultado_geral = os.path.join('../data','scopus-31-05-2021.csv')
resultado_dfs = os.path.join('../data','bases_filtradas-resumida-'+dataFormatada+'.xlsx')
sheetname="bases_filtradas"

df_xlsx_dfs = pd.DataFrame(df_bases_filtrado, columns = [   
    'eid', 'doi', 'titulo_documento', 'titulo_documento_traduzido',#'titulo_documento_scopus','titulo_documento_scopus_traduzido',
    'ano',
    'palavras_chaves_titulo','quantidade_citacoes',
    'resumo', 'resumo_traduzido_google_translator', 'palavras_chaves_resumo', 'conclusao_traduzida', 
     'quantidade_paginas_','status_pagina','link_scopus', 'editor',
    
    # Conferencia
    'nome_conferencia', 'data_conferencia', 'local_conferencia', 'codigo_conferencia',
    
     'idioma_original', 'tipo_documento', 'acesso_livre', 'fonte', 

       'ano_publicacao_pubmed', 'data_criacao_pubmed',
       'doi_pubmed',
       
    # Campos criados para preenchimento
    'documentos_6+', 'documentos_94+', 'pdf_baixado', 'leitura_resumo','leitura_completa', 
       'conceituar_metamap', 'conceituar_farmacovigilancia', 'conceituar_Reacao_adversa_medicamentos_RAM',
       'conceituar_reconhecimento_entidades_nomeadas_REN', 'conceituar_UMLS',
       'conceituar_metamap_data_file_builder_DFB', 'conceituar_ferramenta_lexicos_LVG', 'conceituar_MetamorphoSys',
       'conceituar_NLP', 'conceituar_outros', 'observacao', 'leitura_conclusao',
       'sincronizado_mendeley', 'data_leitura_resumo', 'data_leitura_completa',   
    ])
df_xlsx_dfs = df_xlsx_dfs.to_excel(resultado_dfs,sheet_name=sheetname,index=False, encoding='utf-8', header=True)

# %%
## Gerar planilha com colunas especificas
#resultado_geral = os.path.join('../data','scopus-31-05-2021.csv')
resultado_dfs = os.path.join('../data','bases_filtradas-completa-'+dataFormatada+'.xlsx')
sheetname="bases_completa"

df_xlsx_dfs = pd.DataFrame(df_bases_filtrado, columns = [   
'autores_scopus', 'id_autores', 'titulo_documento', 'ano', 'titulo_fonte',
       'volume', 'publicado', 'numero_documento', 'inicio_pagina', 'fim_pagina',
       'quantidade_paginas', 'quantidade_citacoes', 'doi_scopus',
       'link_scopus', 'afiliacoes', 'autores_com_filiacoes', 'resumo',
       'palavras_chaves_autor', 'palavras_chave_index',
       'numeros_sequencia_molecular', 'chemicals_cas', 'nomes_comerciais',
       'fabricantes', 'detalhes_financiamento', 'texto_financiamento_1',
       'texto_financiamento_2', 'texto_financiamento_3',
       'texto_financiamento_4', 'texto_financiamento_5',
       'texto_financiamento_6', 'texto_financiamento_7',
       'texto_financiamento_8', 'texto_financiamento_9',
       'texto_financiamento_10', 'referencias', 'endereco_correspondencia',
       'editores', 'patrocinadores', 'editor', 'nome_conferencia',
       'data_conferencia', 'local_conferencia', 'codigo_conferencia',
       'issn_scopus', 'isbn', 'coden', 'id_pubmed', 'idioma_original',
       'titulo_abreviado_fonte', 'tipo_documento', 'etapa_publicacao',
       'acesso_livre', 'fonte', 'eid', 'doi', 'titulo_documento_scopus',
       'inicio_pagina_', 'fim_pagina_', 'quantidade_paginas_', 'status_pagina',
       'autores_pubmed', 'citacao_pubmed', 'primeiro_autor_pubmed',
       'jornal_book_pubmed', 'ano_publicacao_pubmed', 'data_criacao_pubmed',
       'id_pmc_pubmed', 'id_nihms_pubmed', 'doi_pubmed',
       'titulo_documento_pubmed', 'documentos_6+', 'documentos_94+',
       'pdf_baixado', 'leitura_resumo', 'leitura_conclusao',
       'leitura_completa', 'resumo_traduzido', 'conclusao_traduzida',
       'conceituar_metamap', 'conceituar_farmacovigilancia',
       'conceituar_Reacao_adversa_medicamentos_RAM',
       'conceituar_reconhecimento_entidades_nomeadas_REN', 'conceituar_UMLS',
       'conceituar_metamap_data_file_builder_DFB',
       'conceituar_ferramenta_lexicos_LVG', 'conceituar_MetamorphoSys',
       'conceituar_NLP', 'conceituar_outros', 'observacao',
       'sincronizado_mendeley', 'data_leitura_resumo', 'data_leitura_completa',
       'palavras_chaves_titulo', 'palavras_chaves_resumo',
       'titulo_documento_scopus_traduzido', 'titulo_documento_pubmed_traduzido',
       'resumo_traduzido_google_translator' 
    ])
df_xlsx_dfs = df_xlsx_dfs.to_excel(resultado_dfs,sheet_name=sheetname,index=False, encoding='utf-8', header=True)

# %% [markdown]
# # Curiosidades

# %% [markdown]
# **dois documentos?**
# <br>
#
# Erratum to: Digital drug safety surveillance: Monitoring pharmaceutical products in Twitter (Drug Safety DOI: 10.1007/s40264-014-0155-x)
#
# <br>
#
# Digital drug safety surveillance: Monitoring pharmaceutical products in Twitter

# %%
data_fim = pd.Timestamp.now()

# %%
print(f'Programa iniciado em: {data_inicio}, e terminado em {data_fim}. Tempo de {data_fim - data_inicio}.')

# %%
print(f'Shape da planinha: {df_bases_filtrado.shape}')

# %% [markdown]
# # Cria arquivo requirements para nova instalação

# %% [raw]
# print('Gerar arquivo com as dependencias necessárias para o projeto.')
# #import pip-chill
# #pip install -r > requirements.txt
# pip freeze
